# %% [markdown]
# ## <div style="text-align: center; background-color: #147eb0;  color: black; padding: 14px; line-height: 0.5;"> <b>EDA on IPL Data</b></div>

# %% [markdown]
# ![IPL.png](attachment:c89c00ca-d3ce-49d8-9565-55007e61e898.png)

# %% [markdown]
# ***

# %% [markdown]
# <h1>IPL Overview :</h1>
# The Indian Premier League (IPL) is a professional Twenty20 cricket league in India, founded by the Board of Control for Cricket in India (BCCI). It is considered to be one of the most popular and lucrative cricket leagues in the world.
#
# The IPL features franchise teams, each representing a different city in India, playing against each other in a double round-robin format, followed by playoffs and a final to determine the champion. The teams are owned by various corporate entities and celebrities, and players are selected through an auction process.
#
# The league has been known for its high-profile players, including Indian stars like Virat Kohli, Rohit Sharma, and MS Dhoni, as well as international players like AB de Villiers, David Warner, and Chris Gayle.
#
# The IPL has become a cultural phenomenon in India, with millions of fans tuning in to watch the matches on television and online streaming platforms. It has also had a significant impact on the economics of cricket, with players earning large sums of money and the league generating substantial revenue through broadcasting rights, sponsorships, and merchandise sales.
#
#
# <h1>About this Dataset :</h1>
# IPL is among the most famous cricket league with players coming from worldwide. What makes this series more competitive every year is the drama with every ball and hence this dataset is a complete dataset showing match information and also data for each delivery.
#
# The file IPL_Matches_2008_2021.csv contains all details of the match: Venue of the match, Toss Decision, Match Winer, Man of the Match, Squads, etc.
# The file IPL_Ball_by_Ball_2008_2021.csv contains ball by ball data of each and every match: Batsman on strike, Bowler, Extras, Runs, Wicket Ball, etc.

# %% [markdown]
# ***

# %% [markdown]
# <h1 style = 'font-family : Calibri'> 📙Table of Contents  </h1> <a class="anchor" id="100"></a>
#
# <div class="list-group" id="list-tab" role="tablist">
#
# * [<b>1. 📚Importing Libraries](#1)
# * [<b>2. 📖Reading Datasets from csv files](#2)
# * [<b>3. 🗄️Data Preparation</b>](#3)
# * [<b>4. 📊Exploratory Data Analysis</b>](#4)
#     - [4.1. 🤼‍♂️Partnership Data Analysis](#4.1)
#         - [4.1.1 🗺️Top 10 Partnerships in IPL](#4.1.1)
#         - [4.1.2 🗺️Season-wise Top Partnerships in IPL](#4.1.2)
#     - [4.2. 🏏Batsmen Data Analysis](#4.2)
#         - [4.2.1 🖼️Top 10 Batsmen](#4.2.1)
#         - [4.2.2 🖼️Top 10 Batsmen Stats](#4.2.2)
#         - [4.2.3 🖼️Top 10 Batsmen Run Details](#4.2.3)
#         - [4.2.5 🖼️Highest 4s hitters in IPL](#4.2.5)
#         - [4.2.6 🖼️Sixer data - Team wise](#4.2.6)
#         - [4.2.7 🖼️Top batsmen score against opponent teams](#4.2.7)
#         - [4.2.8 🖼️Plot for selected batsmen across seasons](#4.2.8)
#     - [4.3. ⛹🏿Bowler Performance Analysis](#4.3)
#         - [4.2.1 🎛️Top 10 wicket takers](#4.3.1)
#         - [4.2.2 🎛️Wicket count against opponent teams](#4.3.2)
#         - [4.2.3 🎛️Hattriks in IPL](#4.3.3)
#     - [4.4. 😊Player of the match Data Analysis](#4.4)
#     - [4.5. 🥇High scores successfully chased](#4.5)
#     - [4.6. 🥉Low scores successfully defended](#4.6)
#     - [4.7. 🎮Win Margin Data Analysis](#4.7)
#     - [4.8. 🏆Head on head encounters (win count on each other)](#4.8)
#     - [4.9. 🏟️Count of matches conducted at each venue](#4.9)
# *[<b>5. Thank You</b>](#5)

# %% [markdown]
# ***

# %% [markdown]
# <a id="1"></a>
#  # <div style="text-align: left; background-color: #147eb0;  color: black; padding: 14px; line-height: 0.5;"> 📚Importing Libraries</div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import colorama
from colorama import Fore, Back, Style

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align: left; background-color: #147eb0;  color: black; padding: 14px; line-height: 0.5;"> 📖Reading Datasets from csv files</div>

# %%
ball_data = pd.read_csv("/kaggle/input/ipl-2008-to-2021-all-match-dataset/IPL_Ball_by_Ball_2008_2022.csv")
match_data = pd.read_csv("/kaggle/input/ipl-2008-to-2021-all-match-dataset/IPL_Matches_2008_2022.csv")

# %%
#let us rename the features
match_data.columns = ['id','city','date','season','matchnumber','team1','team2','venue',
                      'tosswinner','tossdecision','superover','winningteam','wonby','margin',
                      'method','player_of_match','team1players','team2players','umpire1','umpire2']

ball_data.columns  = ['id','inning','over','ballnumber','batter','bowler','non_striker',
                      'extra_type','batsman_run','extras_run','total_runs','non_boundary',
                      'is_wicket', 'player_out','dismissal_kind','fielders_involved','battingteam']
colorsy= ['#0d293f', '#1f4956', '#185175', '#19618f', '#43779a', '#147eb0', '#2d93ca', '#58a9db', '#8ab5d8', '#9ccef0']

# %%
print(Back.GREEN+ Style.BRIGHT+'Match Data'+ Style.RESET_ALL)
match_data2 = match_data.drop(['team1players', 'team2players'], axis=1)
match_data2.head().style.set_properties(**{'background-color': '#cde6f7' ,'border': '1.3px solid black','color':'black','border-color': '#000000'})
# Out:
# Match Data
# <style type="text/css">
# #T_ad7b4_row0_col0, #T_ad7b4_row0_col1, #T_ad7b4_row0_col2, #T_ad7b4_row0_col3, #T_ad7b4_row0_col4, #T_ad7b4_row0_col5, #T_ad7b4_row0_col6, #T_ad7b4_row0_col7, #T_ad7b4_row0_col8, #T_ad7b4_row0_col9, #T_ad7b4_row0_col10, #T_ad7b4_row0_col11, #T_ad7b4_row0_col12, #T_ad7b4_row0_col13, #T_ad7b4_row0_col14, #T_ad7b4_row0_col15, #T_ad7b4_row0_col16, #T_ad7b4_row0_col17, #T_ad7b4_row1_col0, #T_ad7b4_row1_col1, #T_ad7b4_row1_col2, #T_ad7b4_row1_col3, #T_ad7b4_row1_col4, #T_ad7b4_row1_col5, #T_ad7b4_row1_col6, #T_ad7b4_row1_col7, #T_ad7b4_row1_col8, #T_ad7b4_row1_col9, #T_ad7b4_row1_col10, #T_ad7b4_row1_col11, #T_ad7b4_row1_col12, #T_ad7b4_row1_col13, #T_ad7b4_row1_col14, #T_ad7b4_row1_col15, #T_ad7b4_row1_col16, #T_ad7b4_row1_col17, #T_ad7b4_row2_col0, #T_ad7b4_row2_col1, #T_ad7b4_row2_col2, #T_ad7b4_row2_col3, #T_ad7b4_row2_col4, #T_ad7b4_row2_col5, #T_ad7b4_row2_col6, #T_ad7b4_row2_col7, #T_ad7b4_row2_col8, #T_ad7b4_row2_col9, #T_ad7b4_row2_col10, #T_ad7b4_row2_col11, #T_ad7b4_row2_col12, #T_ad7b4_row2_col13, #T_ad7b4_row2_col14, #T_ad7b4_row2_col15, #T_ad7b4_row2_col16, #T_ad7b4_row2_col17, #T_ad7b4_row3_col0, #T_ad7b4_row3_col1, #T_ad7b4_row3_col2, #T_ad7b4_row3_col3, #T_ad7b4_row3_col4, #T_ad7b4_row3_col5, #T_ad7b4_row3_col6, #T_ad7b4_row3_col7, #T_ad7b4_row3_col8, #T_ad7b4_row3_col9, #T_ad7b4_row3_col10, #T_ad7b4_row3_col11, #T_ad7b4_row3_col12, #T_ad7b4_row3_col13, #T_ad7b4_row3_col14, #T_ad7b4_row3_col15, #T_ad7b4_row3_col16, #T_ad7b4_row3_col17, #T_ad7b4_row4_col0, #T_ad7b4_row4_col1, #T_ad7b4_row4_col2, #T_ad7b4_row4_col3, #T_ad7b4_row4_col4, #T_ad7b4_row4_col5, #T_ad7b4_row4_col6, #T_ad7b4_row4_col7, #T_ad7b4_row4_col8, #T_ad7b4_row4_col9, #T_ad7b4_row4_col10, #T_ad7b4_row4_col11, #T_ad7b4_row4_col12, #T_ad7b4_row4_col13, #T_ad7b4_row4_col14, #T_ad7b4_row4_col15, #T_ad7b4_row4_col16, #T_ad7b4_row4_col17 {
#   background-color: #cde6f7;
#   border: 1.3px solid black;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_ad7b4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >city</th>
#       <th class="col_heading level0 col2" >date</th>
#       <th class="col_heading level0 col3" >season</th>
#       <th class="col_heading level0 col4" >matchnumber</th>
#       <th class="col_heading level0 col5" >team1</th>
#       <th class="col_heading level0 col6" >team2</th>
#       <th class="col_heading level0 col7" >venue</th>
#       <th class="col_heading level0 col8" >tosswinner</th>
#       <th class="col_heading level0 col9" >tossdecision</th>
#       <th class="col_heading level0 col10" >superover</th>
#       <th class="col_heading level0 col11" >winningteam</th>
#       <th class="col_heading level0 col12" >wonby</th>
#       <th class="col_heading level0 col13" >margin</th>
#       <th class="col_heading level0 col14" >method</th>
#       <th class="col_heading level0 col15" >player_of_match</th>
#       <th class="col_heading level0 col16" >umpire1</th>
#       <th class="col_heading level0 col17" >umpire2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad7b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad7b4_row0_col0" class="data row0 col0" >1312200</td>
#       <td id="T_ad7b4_row0_col1" class="data row0 col1" >Ahmedabad</td>
#       <td id="T_ad7b4_row0_col2" class="data row0 col2" >2022-05-29</td>
#       <td id="T_ad7b4_row0_col3" class="data row0 col3" >2022</td>
#       <td id="T_ad7b4_row0_col4" class="data row0 col4" >Final</td>
#       <td id="T_ad7b4_row0_col5" class="data row0 col5" >Rajasthan Royals</td>
#       <td id="T_ad7b4_row0_col6" class="data row0 col6" >Gujarat Titans</td>
#       <td id="T_ad7b4_row0_col7" class="data row0 col7" >Narendra Modi Stadium, Ahmedabad</td>
#       <td id="T_ad7b4_row0_col8" class="data row0 col8" >Rajasthan Royals</td>
#       <td id="T_ad7b4_row0_col9" class="data row0 col9" >bat</td>
#       <td id="T_ad7b4_row0_col10" class="data row0 col10" >N</td>
#       <td id="T_ad7b4_row0_col11" class="data row0 col11" >Gujarat Titans</td>
#       <td id="T_ad7b4_row0_col12" class="data row0 col12" >Wickets</td>
#       <td id="T_ad7b4_row0_col13" class="data row0 col13" >7.000000</td>
#       <td id="T_ad7b4_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_ad7b4_row0_col15" class="data row0 col15" >HH Pandya</td>
#       <td id="T_ad7b4_row0_col16" class="data row0 col16" >CB Gaffaney</td>
#       <td id="T_ad7b4_row0_col17" class="data row0 col17" >Nitin Menon</td>
#     </tr>
#     <tr>
#       <th id="T_ad7b4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad7b4_row1_col0" class="data row1 col0" >1312199</td>
#       <td id="T_ad7b4_row1_col1" class="data row1 col1" >Ahmedabad</td>
#       <td id="T_ad7b4_row1_col2" class="data row1 col2" >2022-05-27</td>
#       <td id="T_ad7b4_row1_col3" class="data row1 col3" >2022</td>
#       <td id="T_ad7b4_row1_col4" class="data row1 col4" >Qualifier 2</td>
#       <td id="T_ad7b4_row1_col5" class="data row1 col5" >Royal Challengers Bangalore</td>
#       <td id="T_ad7b4_row1_col6" class="data row1 col6" >Rajasthan Royals</td>
#       <td id="T_ad7b4_row1_col7" class="data row1 col7" >Narendra Modi Stadium, Ahmedabad</td>
#       <td id="T_ad7b4_row1_col8" class="data row1 col8" >Rajasthan Royals</td>
#       <td id="T_ad7b4_row1_col9" class="data row1 col9" >field</td>
#       <td id="T_ad7b4_row1_col10" class="data row1 col10" >N</td>
#       <td id="T_ad7b4_row1_col11" class="data row1 col11" >Rajasthan Royals</td>
#       <td id="T_ad7b4_row1_col12" class="data row1 col12" >Wickets</td>
#       <td id="T_ad7b4_row1_col13" class="data row1 col13" >7.000000</td>
#       <td id="T_ad7b4_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_ad7b4_row1_col15" class="data row1 col15" >JC Buttler</td>
#       <td id="T_ad7b4_row1_col16" class="data row1 col16" >CB Gaffaney</td>
#       <td id="T_ad7b4_row1_col17" class="data row1 col17" >Nitin Menon</td>
#     </tr>
#     <tr>
#       <th id="T_ad7b4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad7b4_row2_col0" class="data row2 col0" >1312198</td>
#       <td id="T_ad7b4_row2_col1" class="data row2 col1" >Kolkata</td>
#       <td id="T_ad7b4_row2_col2" class="data row2 col2" >2022-05-25</td>
#       <td id="T_ad7b4_row2_col3" class="data row2 col3" >2022</td>
#       <td id="T_ad7b4_row2_col4" class="data row2 col4" >Eliminator</td>
#       <td id="T_ad7b4_row2_col5" class="data row2 col5" >Royal Challengers Bangalore</td>
#       <td id="T_ad7b4_row2_col6" class="data row2 col6" >Lucknow Super Giants</td>
#       <td id="T_ad7b4_row2_col7" class="data row2 col7" >Eden Gardens, Kolkata</td>
#       <td id="T_ad7b4_row2_col8" class="data row2 col8" >Lucknow Super Giants</td>
#       <td id="T_ad7b4_row2_col9" class="data row2 col9" >field</td>
#       <td id="T_ad7b4_row2_col10" class="data row2 col10" >N</td>
#       <td id="T_ad7b4_row2_col11" class="data row2 col11" >Royal Challengers Bangalore</td>
#       <td id="T_ad7b4_row2_col12" class="data row2 col12" >Runs</td>
#       <td id="T_ad7b4_row2_col13" class="data row2 col13" >14.000000</td>
#       <td id="T_ad7b4_row2_col14" class="data row2 col14" >nan</td>
#       <td id="T_ad7b4_row2_col15" class="data row2 col15" >RM Patidar</td>
#       <td id="T_ad7b4_row2_col16" class="data row2 col16" >J Madanagopal</td>
#       <td id="T_ad7b4_row2_col17" class="data row2 col17" >MA Gough</td>
#     </tr>
#     <tr>
#       <th id="T_ad7b4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad7b4_row3_col0" class="data row3 col0" >1312197</td>
#       <td id="T_ad7b4_row3_col1" class="data row3 col1" >Kolkata</td>
#       <td id="T_ad7b4_row3_col2" class="data row3 col2" >2022-05-24</td>
#       <td id="T_ad7b4_row3_col3" class="data row3 col3" >2022</td>
#       <td id="T_ad7b4_row3_col4" class="data row3 col4" >Qualifier 1</td>
#       <td id="T_ad7b4_row3_col5" class="data row3 col5" >Rajasthan Royals</td>
#       <td id="T_ad7b4_row3_col6" class="data row3

# %%
print(Back.GREEN+ Style.BRIGHT+'Ball Data'+ Style.RESET_ALL)
ball_data.head().style.set_properties(**{'background-color': '#cde6f7' ,'border': '1.3px solid black','color':'black','border-color': '#000000'})
# Out:
# Ball Data
# <style type="text/css">
# #T_02cdc_row0_col0, #T_02cdc_row0_col1, #T_02cdc_row0_col2, #T_02cdc_row0_col3, #T_02cdc_row0_col4, #T_02cdc_row0_col5, #T_02cdc_row0_col6, #T_02cdc_row0_col7, #T_02cdc_row0_col8, #T_02cdc_row0_col9, #T_02cdc_row0_col10, #T_02cdc_row0_col11, #T_02cdc_row0_col12, #T_02cdc_row0_col13, #T_02cdc_row0_col14, #T_02cdc_row0_col15, #T_02cdc_row0_col16, #T_02cdc_row1_col0, #T_02cdc_row1_col1, #T_02cdc_row1_col2, #T_02cdc_row1_col3, #T_02cdc_row1_col4, #T_02cdc_row1_col5, #T_02cdc_row1_col6, #T_02cdc_row1_col7, #T_02cdc_row1_col8, #T_02cdc_row1_col9, #T_02cdc_row1_col10, #T_02cdc_row1_col11, #T_02cdc_row1_col12, #T_02cdc_row1_col13, #T_02cdc_row1_col14, #T_02cdc_row1_col15, #T_02cdc_row1_col16, #T_02cdc_row2_col0, #T_02cdc_row2_col1, #T_02cdc_row2_col2, #T_02cdc_row2_col3, #T_02cdc_row2_col4, #T_02cdc_row2_col5, #T_02cdc_row2_col6, #T_02cdc_row2_col7, #T_02cdc_row2_col8, #T_02cdc_row2_col9, #T_02cdc_row2_col10, #T_02cdc_row2_col11, #T_02cdc_row2_col12, #T_02cdc_row2_col13, #T_02cdc_row2_col14, #T_02cdc_row2_col15, #T_02cdc_row2_col16, #T_02cdc_row3_col0, #T_02cdc_row3_col1, #T_02cdc_row3_col2, #T_02cdc_row3_col3, #T_02cdc_row3_col4, #T_02cdc_row3_col5, #T_02cdc_row3_col6, #T_02cdc_row3_col7, #T_02cdc_row3_col8, #T_02cdc_row3_col9, #T_02cdc_row3_col10, #T_02cdc_row3_col11, #T_02cdc_row3_col12, #T_02cdc_row3_col13, #T_02cdc_row3_col14, #T_02cdc_row3_col15, #T_02cdc_row3_col16, #T_02cdc_row4_col0, #T_02cdc_row4_col1, #T_02cdc_row4_col2, #T_02cdc_row4_col3, #T_02cdc_row4_col4, #T_02cdc_row4_col5, #T_02cdc_row4_col6, #T_02cdc_row4_col7, #T_02cdc_row4_col8, #T_02cdc_row4_col9, #T_02cdc_row4_col10, #T_02cdc_row4_col11, #T_02cdc_row4_col12, #T_02cdc_row4_col13, #T_02cdc_row4_col14, #T_02cdc_row4_col15, #T_02cdc_row4_col16 {
#   background-color: #cde6f7;
#   border: 1.3px solid black;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_02cdc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >inning</th>
#       <th class="col_heading level0 col2" >over</th>
#       <th class="col_heading level0 col3" >ballnumber</th>
#       <th class="col_heading level0 col4" >batter</th>
#       <th class="col_heading level0 col5" >bowler</th>
#       <th class="col_heading level0 col6" >non_striker</th>
#       <th class="col_heading level0 col7" >extra_type</th>
#       <th class="col_heading level0 col8" >batsman_run</th>
#       <th class="col_heading level0 col9" >extras_run</th>
#       <th class="col_heading level0 col10" >total_runs</th>
#       <th class="col_heading level0 col11" >non_boundary</th>
#       <th class="col_heading level0 col12" >is_wicket</th>
#       <th class="col_heading level0 col13" >player_out</th>
#       <th class="col_heading level0 col14" >dismissal_kind</th>
#       <th class="col_heading level0 col15" >fielders_involved</th>
#       <th class="col_heading level0 col16" >battingteam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02cdc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02cdc_row0_col0" class="data row0 col0" >1312200</td>
#       <td id="T_02cdc_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_02cdc_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_02cdc_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_02cdc_row0_col4" class="data row0 col4" >YBK Jaiswal</td>
#       <td id="T_02cdc_row0_col5" class="data row0 col5" >Mohammed Shami</td>
#       <td id="T_02cdc_row0_col6" class="data row0 col6" >JC Buttler</td>
#       <td id="T_02cdc_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_02cdc_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_02cdc_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_02cdc_row0_col10" class="data row0 col10" >0</td>
#       <td id="T_02cdc_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_02cdc_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_02cdc_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_02cdc_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_02cdc_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_02cdc_row0_col16" class="data row0 col16" >Rajasthan Royals</td>
#     </tr>
#     <tr>
#       <th id="T_02cdc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_02cdc_row1_col0" class="data row1 col0" >1312200</td>
#       <td id="T_02cdc_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_02cdc_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_02cdc_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_02cdc_row1_col4" class="data row1 col4" >YBK Jaiswal</td>
#       <td id="T_02cdc_row1_col5" class="data row1 col5" >Mohammed Shami</td>
#       <td id="T_02cdc_row1_col6" class="data row1 col6" >JC Buttler</td>
#       <td id="T_02cdc_row1_col7" class="data row1 col7" >legbyes</td>
#       <td id="T_02cdc_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_02cdc_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_02cdc_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_02cdc_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_02cdc_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_02cdc_row1_col13" class="data row1 col13" >nan</td>
#       <td id="T_02cdc_row1_col14" class="data row1 col14" >nan</td>
#       <td id="T_02cdc_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_02cdc_row1_col16" class="data row1 col16" >Rajasthan Royals</td>
#     </tr>
#     <tr>
#       <th id="T_02cdc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_02cdc_row2_col0" class="data row2 col0" >1312200</td>
#       <td id="T_02cdc_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_02cdc_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_02cdc_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_02cdc_row2_col4" class="data row2 col4" >JC Buttler</td>
#       <td id="T_02cdc_row2_col5" class="data row2 col5" >Mohammed Shami</td>
#       <td id="T_02cdc_row2_col6" class="data row2 col6" >YBK Jaiswal</td>
#       <td id="T_02cdc_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_02cdc_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_02cdc_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_02cdc_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_02cdc_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_02cdc_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_02cdc_row2_col13" class="data row2 col13" >nan</td>
#       <td id="T_02cdc_row2_col14" class="data row2 col14" >nan</td>
#       <td id="T_02cdc_row2_col15" class="data row2 col15" >nan</td>
#       <td id="T_02cdc_row2_col16" class="data row2 col16" >Rajasthan Royals</td>
#     </tr>
#     <tr>
#       <th id="T_02cdc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_02cdc_row3_col0" class="data row3 col0" >1312200</td>
#       <td id="T_02cdc_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_02cdc_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_02cdc_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_02cdc_row3_col4" class="data row3 col4" >YBK Jaiswal</td>
#       <td id="T_02cdc_row3_col5" class="data row3 col5" >Mohammed Shami</td>
#       <td id="T_02cdc_row3_col6" class="data row3 col6" >JC Buttler</td>
#       <td id="T_02cdc_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_02cdc_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_02cdc_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_02cdc_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_02cdc_row3_col11" class="data row3 col11" >0</td>
#       <td id="T_02cdc_row3_col12" class="data row3 col12" >0</td>
#       <td id="T_02cdc_row3_col13" class="data row3 col13" >nan</td>
#       <td id="T_02cdc_row3_col14" class="data row3 col14" >nan</td>
#       <td id="T_02cdc_row3_col15" class="data row3 col15" >nan</td>
#       <td id="T_02cdc_row3_col16" class="data row3 col16" >Rajasthan Royal

# %% [markdown]
# <a id="3"></a>
# # <div style="text-align: left; background-color: #147eb0;  color: black; padding: 14px; line-height: 0.5;"> 🗄️Data Preparation</div>

# %%
#Let us add new derived features to the ball_data Dataframe...
ball_data['bowlingteam'] = ''
ball_data['first_batter'] = ''
ball_data['second_batter'] = ''

# %%
#In ball_data, we have two types of rows, which are to be treated as same for computing the partnership
#batter        non-striker
#-------------------------
#YBK Jaiswal   JC Buttler
#JC Buttler    YBK Jaiswal

#So we will be creating two new features as below and use them from partnership calculation
#first_batter second_batter
#--------------------------
#JC Buttler    YBK Jaiswal
#JC Buttler    YBK Jaiswal

ball_data['first_batter']  = ball_data.apply(lambda x: x['batter'] if x['batter']  <  x['non_striker'] else x['non_striker'], axis=1)
ball_data['second_batter'] = ball_data.apply(lambda x: x['non_striker'] if x['batter']  <  x['non_striker'] else x['batter'], axis=1)

# %%
#In ball_data,we have battingteam feature, let us add bowlingteam fature
#Let us add season info too..
ball_data = pd.merge(ball_data, match_data[['id','team1','team2','season']], how='left', on='id')
ball_data['bowlingteam'] = ball_data.apply(lambda x: x['team2'] if x['battingteam'] == x['team1'] else x['team1'], axis=1)

# %%
#In match_data, we have winningteam team feature and let us add win_against feature to it
match_data['win_against'] = match_data.apply(lambda x: x['team2'] if x['winningteam'] == x['team1'] else x['team1'], axis=1)

# %% [markdown]
# <a id="4"></a>
# # <div style="text-align: left; background-color: #147eb0;  color: black; padding: 14px; line-height: 0.5;"> 📊Exploratory Data Analysis</div>

# %% [markdown]
# <a id="4.1"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🤼‍Partnership Data Analysis</div>

# %% [markdown]
# <a id="4.1.1"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🗺️Top 10 Partnerships in IPL</div>

# %%
#To find Top 10 partnerships in IPL History
partnership_data=ball_data.groupby(['id','season','first_batter', 'second_batter','battingteam','bowlingteam'])\
                    .agg(partnership=('total_runs','sum')).reset_index()
top10_partnerships = partnership_data.sort_values(by='partnership',ascending=False).head(10)
top10_partnerships = top10_partnerships.sort_values(by='partnership',ascending=True)

fig = go.Figure(data=px.bar(x=top10_partnerships.battingteam, 
                            y=top10_partnerships.partnership,
                            color = top10_partnerships.first_batter+' & '+top10_partnerships.second_batter,
                            color_discrete_sequence=colorsy,
                            title='<b>Top 10 Partnerships in IPL</b>',
                            text = top10_partnerships.partnership,
                            height=500))
fig.update_layout(
    font_family="Courier New",
    title_font_family="Times New Roman",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Batting Team</b>",
    yaxis_title="<b>Partnership</b>",
    legend_title_font_color="green"
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="7abc0352-9681-4d34-a712-17c44439f386" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7abc0352-9681-4d34-a712-17c44439f386")) {                    Plotly.newPlot(                        "7abc0352-9681-4d34-a712-17c44439f386",                        [{"alignmentgroup":"True","hovertemplate":"color=DP Conway & RD Gaikwad<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"DP Conway & RD Gaikwad","marker":{"color":"#0d293f","pattern":{"shape":""}},"name":"DP Conway & RD Gaikwad","offsetgroup":"DP Conway & RD Gaikwad","orientation":"v","showlegend":true,"text":[182.0],"textposition":"auto","x":["Chennai Super Kings"],"xaxis":"x","y":[182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=KL Rahul & MA Agarwal<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"KL Rahul & MA Agarwal","marker":{"color":"#1f4956","pattern":{"shape":""}},"name":"KL Rahul & MA Agarwal","offsetgroup":"KL Rahul & MA Agarwal","orientation":"v","showlegend":true,"text":[183.0],"textposition":"auto","x":["Kings XI Punjab"],"xaxis":"x","y":[183],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=CA Lynn & G Gambhir<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"CA Lynn & G Gambhir","marker":{"color":"#185175","pattern":{"shape":""}},"name":"CA Lynn & G Gambhir","offsetgroup":"CA Lynn & G Gambhir","orientation":"v","showlegend":true,"text":[184.0],"textposition":"auto","x":["Kolkata Knight Riders"],"xaxis":"x","y":[184],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=DA Warner & JM Bairstow<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"DA Warner & JM Bairstow","marker":{"color":"#19618f","pattern":{"shape":""}},"name":"DA Warner & JM Bairstow","offsetgroup":"DA Warner & JM Bairstow","orientation":"v","showlegend":true,"text":[185.0],"textposition":"auto","x":["Sunrisers Hyderabad"],"xaxis":"x","y":[185],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=DA Warner & NV Ojha<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"DA Warner & NV Ojha","marker":{"color":"#43779a","pattern":{"shape":""}},"name":"DA Warner & NV Ojha","offsetgroup":"DA Warner & NV Ojha","orientation":"v","showlegend":true,"text":[189.0],"textposition":"auto","x":["Delhi Daredevils"],"xaxis":"x","y":[189],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=CH Gayle & V Kohli<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"CH Gayle & V Kohli","marker":{"color":"#147eb0","pattern":{"shape":""}},"name":"CH Gayle & V Kohli","offsetgroup":"CH Gayle & V Kohli","orientation":"v","showlegend":true,"text":[204.0],"textposition":"auto","x":["Royal Challengers Bangalore"],"xaxis":"x","y":[204],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AC Gilchrist & SE Marsh<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"AC Gilchrist & SE Marsh","marker":{"color":"#2d93ca","pattern":{"shape":""}},"name":"AC Gilchrist & SE Marsh","offsetgroup":"AC Gilchrist & SE Marsh","orientation":"v","showlegend":true,"text":[206.0],"textposition":"auto","x":["Kings XI Punjab"],"xaxis":"x","y":[206],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=KL Rahul & Q de Kock<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"KL Rahul & Q de Kock","marker":{"color":"#58a9db","pattern":{"shape":""}},"name":"KL Rahul & Q de Kock","offsetgroup":"KL Rahul & Q de Kock","orientation":"v","showlegend":true,"text":[210.0],"textposition":"auto","x":["Lucknow Super Giants"],"xaxis":"x","y":[210],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate": ...

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     <b>Royal Challengers Bangalore</b> holds 3 out top 10 Partnerships in IPL history. Highest Partnership being <b>229</b> made by <b>AB de Villiers</b> and <b>V Kohli</b>.</div>

# %% [markdown]
# <a id="4.1.2"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🗺️Season-wise Top Partnerships in IPL</div>

# %%
#To find top partnerships per season
partnership_data['Rank'] = partnership_data.groupby('season')['partnership'].rank(ascending=False)
season_top_partnership=partnership_data[partnership_data['Rank']==1].sort_values('season')
#season_top_partnership

fig = go.Figure(data=px.bar(x=season_top_partnership.season, 
                            y=season_top_partnership.partnership,
                            color = season_top_partnership.first_batter+' & '+season_top_partnership.second_batter,
                            color_discrete_sequence=colorsy,
                            title='<b>Season-wise Top Partnerships in IPL</b>',
                            text = season_top_partnership.partnership,
                            height=500))
fig.update_layout(
    font_family="Courier New",
    title_font_family="Times New Roman",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Season</b>",
    yaxis_title="<b>Partnership</b>",
    legend_title_font_color="green"
)
fig.show()
# Out:
# <div>                            <div id="3f6cfed2-16a2-4fc1-b7cc-f87990fa9b73" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f6cfed2-16a2-4fc1-b7cc-f87990fa9b73")) {                    Plotly.newPlot(                        "3f6cfed2-16a2-4fc1-b7cc-f87990fa9b73",                        [{"alignmentgroup":"True","hovertemplate":"color=AC Gilchrist & VVS Laxman<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"AC Gilchrist & VVS Laxman","marker":{"color":"#0d293f","pattern":{"shape":""}},"name":"AC Gilchrist & VVS Laxman","offsetgroup":"AC Gilchrist & VVS Laxman","orientation":"v","showlegend":true,"text":[155.0],"textposition":"auto","x":["2007/08"],"xaxis":"x","y":[155],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=GC Smith & NV Ojha<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"GC Smith & NV Ojha","marker":{"color":"#1f4956","pattern":{"shape":""}},"name":"GC Smith & NV Ojha","offsetgroup":"GC Smith & NV Ojha","orientation":"v","showlegend":true,"text":[135.0],"textposition":"auto","x":["2009"],"xaxis":"x","y":[135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=JA Morkel & M Vijay<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"JA Morkel & M Vijay","marker":{"color":"#185175","pattern":{"shape":""}},"name":"JA Morkel & M Vijay","offsetgroup":"JA Morkel & M Vijay","orientation":"v","showlegend":true,"text":[152.0],"textposition":"auto","x":["2009/10"],"xaxis":"x","y":[152],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AC Gilchrist & SE Marsh<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"AC Gilchrist & SE Marsh","marker":{"color":"#19618f","pattern":{"shape":""}},"name":"AC Gilchrist & SE Marsh","offsetgroup":"AC Gilchrist & SE Marsh","orientation":"v","showlegend":true,"text":[206.0],"textposition":"auto","x":["2011"],"xaxis":"x","y":[206],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=CH Gayle & V Kohli<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"CH Gayle & V Kohli","marker":{"color":"#43779a","pattern":{"shape":""}},"name":"CH Gayle & V Kohli","offsetgroup":"CH Gayle & V Kohli","orientation":"v","showlegend":true,"text":[204.0],"textposition":"auto","x":["2012"],"xaxis":"x","y":[204],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=CH Gayle & TM Dilshan<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"CH Gayle & TM Dilshan","marker":{"color":"#147eb0","pattern":{"shape":""}},"name":"CH Gayle & TM Dilshan","offsetgroup":"CH Gayle & TM Dilshan","orientation":"v","showlegend":true,"text":[167.0],"textposition":"auto","x":["2013"],"xaxis":"x","y":[167],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=DA Miller & GJ Maxwell<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"DA Miller & GJ Maxwell","marker":{"color":"#2d93ca","pattern":{"shape":""}},"name":"DA Miller & GJ Maxwell","offsetgroup":"DA Miller & GJ Maxwell","orientation":"v","showlegend":true,"text":[135.0],"textposition":"auto","x":["2014"],"xaxis":"x","y":[135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AB de Villiers & V Kohli<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"AB de Villiers & V Kohli","marker":{"color":"#58a9db","pattern":{"shape":""}},"name":"AB de Villiers & V Kohli","offsetgroup":"AB de Villiers & V Kohli","orientation":"v","showlegend":true,"text":[215.0,229.0],"textposition":"auto","x":["2015","2016"],"xaxis":"x","y":[215,229],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=CA Lynn & G Gambhir<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra> ...

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     <b>AB de Villiers</b> and <b>V Kohli</b> of <b>Royal Challengers Bangalore</b> made the highest partnership of <b>229</b> in <b>2016</b> season .</div>

# %% [markdown]
# <a id="4.2"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🏏Batsmen Data Analysis</div>

# %% [markdown]
# <a id="4.2.1"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Top 10 Batsmen</div>

# %%
#Let us list the top 10 batsmen based on the total runs they made in IPL
top_batsman=ball_data.groupby(['batter']).agg(batsman_total=('batsman_run', 'sum')).reset_index()\
                .sort_values(by='batsman_total', ascending=False).head(10)

fig = px.pie(values=top_batsman.batsman_total, 
             names=top_batsman.batter,
             color_discrete_sequence=px.colors.sequential.Plasma)
fig.update_traces(textposition='inside',
                  textfont_size=11,
                  textinfo='value+label')

fig.update_layout(title_text="<b>Top 10 Batsmen</b>",
                  title_font_family="Times New Roman",
                  title_font_color="red",
                  title_font_size=20,
                  uniformtext_minsize=12, 
                  uniformtext_mode='hide')

fig.show()
# Out:
# <div>                            <div id="7b29f0fc-aaf3-4dd1-9605-3e89314c4852" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b29f0fc-aaf3-4dd1-9605-3e89314c4852")) {                    Plotly.newPlot(                        "7b29f0fc-aaf3-4dd1-9605-3e89314c4852",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["V Kohli","S Dhawan","DA Warner","RG Sharma","SK Raina","AB de Villiers","CH Gayle","MS Dhoni","RV Uthappa","KD Karthik"],"legendgroup":"","name":"","showlegend":true,"values":[6634,6244,5883,5881,5536,5181,4997,4978,4954,4377],"type":"pie","textfont":{"size":11},"textinfo":"value+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"o ...

# %% [markdown]
# <a id="4.2.2"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Top 10 Batsmen Stats</div>

# %%
print(Back.GREEN+ Style.BRIGHT+'Top 10 Batsmen Score Details'+ Style.RESET_ALL)
top_batsman_score = pd.DataFrame(columns=['batsman', 'fours', 'sixers', 'fifties', 'hundreds','heighest_score','total_runs', 'matches_played'])
for idx, row in top_batsman.iterrows():
    batsman_data = ball_data[ball_data['batter'] == row['batter']][['id', 'batter', 'batsman_run']]

    r4 = len(batsman_data[batsman_data['batsman_run'] == 4])
    r6 = len(batsman_data[batsman_data['batsman_run'] == 6])

    innings_score = batsman_data.groupby('id').agg(score=('batsman_run', 'sum')).reset_index()
    r50=len(innings_score[(innings_score['score'] >=50) & (innings_score['score'] < 100)])
    r100 = len(innings_score[innings_score['score'] >= 100])
    matches_played =  len(innings_score)
    heighest_score = innings_score['score'].max()


    top_batsman_score = top_batsman_score.append({'batsman': row['batter'], 'fours': r4, 'sixers': r6, 'fifties':r50,
                                                  'hundreds':r100, 'total_runs':row['batsman_total'],
                                                  'heighest_score':heighest_score,
                                                  'matches_played':matches_played},ignore_index=True)

top_batsman_score.style.set_properties(**{'background-color': '#cde6f7' ,'border': '1.3px solid black','color':'black','border-color': '#000000'})
# Out:
# Top 10 Batsmen Score Details
# <style type="text/css">
# #T_669d0_row0_col0, #T_669d0_row0_col1, #T_669d0_row0_col2, #T_669d0_row0_col3, #T_669d0_row0_col4, #T_669d0_row0_col5, #T_669d0_row0_col6, #T_669d0_row0_col7, #T_669d0_row1_col0, #T_669d0_row1_col1, #T_669d0_row1_col2, #T_669d0_row1_col3, #T_669d0_row1_col4, #T_669d0_row1_col5, #T_669d0_row1_col6, #T_669d0_row1_col7, #T_669d0_row2_col0, #T_669d0_row2_col1, #T_669d0_row2_col2, #T_669d0_row2_col3, #T_669d0_row2_col4, #T_669d0_row2_col5, #T_669d0_row2_col6, #T_669d0_row2_col7, #T_669d0_row3_col0, #T_669d0_row3_col1, #T_669d0_row3_col2, #T_669d0_row3_col3, #T_669d0_row3_col4, #T_669d0_row3_col5, #T_669d0_row3_col6, #T_669d0_row3_col7, #T_669d0_row4_col0, #T_669d0_row4_col1, #T_669d0_row4_col2, #T_669d0_row4_col3, #T_669d0_row4_col4, #T_669d0_row4_col5, #T_669d0_row4_col6, #T_669d0_row4_col7, #T_669d0_row5_col0, #T_669d0_row5_col1, #T_669d0_row5_col2, #T_669d0_row5_col3, #T_669d0_row5_col4, #T_669d0_row5_col5, #T_669d0_row5_col6, #T_669d0_row5_col7, #T_669d0_row6_col0, #T_669d0_row6_col1, #T_669d0_row6_col2, #T_669d0_row6_col3, #T_669d0_row6_col4, #T_669d0_row6_col5, #T_669d0_row6_col6, #T_669d0_row6_col7, #T_669d0_row7_col0, #T_669d0_row7_col1, #T_669d0_row7_col2, #T_669d0_row7_col3, #T_669d0_row7_col4, #T_669d0_row7_col5, #T_669d0_row7_col6, #T_669d0_row7_col7, #T_669d0_row8_col0, #T_669d0_row8_col1, #T_669d0_row8_col2, #T_669d0_row8_col3, #T_669d0_row8_col4, #T_669d0_row8_col5, #T_669d0_row8_col6, #T_669d0_row8_col7, #T_669d0_row9_col0, #T_669d0_row9_col1, #T_669d0_row9_col2, #T_669d0_row9_col3, #T_669d0_row9_col4, #T_669d0_row9_col5, #T_669d0_row9_col6, #T_669d0_row9_col7 {
#   background-color: #cde6f7;
#   border: 1.3px solid black;
#   color: black;
#   border-color: #000000;
# }
# </style>
# <table id="T_669d0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >batsman</th>
#       <th class="col_heading level0 col1" >fours</th>
#       <th class="col_heading level0 col2" >sixers</th>
#       <th class="col_heading level0 col3" >fifties</th>
#       <th class="col_heading level0 col4" >hundreds</th>
#       <th class="col_heading level0 col5" >heighest_score</th>
#       <th class="col_heading level0 col6" >total_runs</th>
#       <th class="col_heading level0 col7" >matches_played</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_669d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_669d0_row0_col0" class="data row0 col0" >V Kohli</td>
#       <td id="T_669d0_row0_col1" class="data row0 col1" >581</td>
#       <td id="T_669d0_row0_col2" class="data row0 col2" >219</td>
#       <td id="T_669d0_row0_col3" class="data row0 col3" >45</td>
#       <td id="T_669d0_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_669d0_row0_col5" class="data row0 col5" >113</td>
#       <td id="T_669d0_row0_col6" class="data row0 col6" >6634</td>
#       <td id="T_669d0_row0_col7" class="data row0 col7" >215</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_669d0_row1_col0" class="data row1 col0" >S Dhawan</td>
#       <td id="T_669d0_row1_col1" class="data row1 col1" >701</td>
#       <td id="T_669d0_row1_col2" class="data row1 col2" >137</td>
#       <td id="T_669d0_row1_col3" class="data row1 col3" >47</td>
#       <td id="T_669d0_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_669d0_row1_col5" class="data row1 col5" >106</td>
#       <td id="T_669d0_row1_col6" class="data row1 col6" >6244</td>
#       <td id="T_669d0_row1_col7" class="data row1 col7" >205</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_669d0_row2_col0" class="data row2 col0" >DA Warner</td>
#       <td id="T_669d0_row2_col1" class="data row2 col1" >577</td>
#       <td id="T_669d0_row2_col2" class="data row2 col2" >216</td>
#       <td id="T_669d0_row2_col3" class="data row2 col3" >55</td>
#       <td id="T_669d0_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_669d0_row2_col5" class="data row2 col5" >126</td>
#       <td id="T_669d0_row2_col6" class="data row2 col6" >5883</td>
#       <td id="T_669d0_row2_col7" class="data row2 col7" >162</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_669d0_row3_col0" class="data row3 col0" >RG Sharma</td>
#       <td id="T_669d0_row3_col1" class="data row3 col1" >519</td>
#       <td id="T_669d0_row3_col2" class="data row3 col2" >241</td>
#       <td id="T_669d0_row3_col3" class="data row3 col3" >40</td>
#       <td id="T_669d0_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_669d0_row3_col5" class="data row3 col5" >109</td>
#       <td id="T_669d0_row3_col6" class="data row3 col6" >5881</td>
#       <td id="T_669d0_row3_col7" class="data row3 col7" >221</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_669d0_row4_col0" class="data row4 col0" >SK Raina</td>
#       <td id="T_669d0_row4_col1" class="data row4 col1" >506</td>
#       <td id="T_669d0_row4_col2" class="data row4 col2" >204</td>
#       <td id="T_669d0_row4_col3" class="data row4 col3" >39</td>
#       <td id="T_669d0_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_669d0_row4_col5" class="data row4 col5" >100</td>
#       <td id="T_669d0_row4_col6" class="data row4 col6" >5536</td>
#       <td id="T_669d0_row4_col7" class="data row4 col7" >200</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_669d0_row5_col0" class="data row5 col0" >AB de Villiers</td>
#       <td id="T_669d0_row5_col1" class="data row5 col1" >414</td>
#       <td id="T_669d0_row5_col2" class="data row5 col2" >253</td>
#       <td id="T_669d0_row5_col3" class="data row5 col3" >41</td>
#       <td id="T_669d0_row5_col4" class="data row5 col4" >3</td>
#       <td id="T_669d0_row5_col5" class="data row5 col5" >133</td>
#       <td id="T_669d0_row5_col6" class="data row5 col6" >5181</td>
#       <td id="T_669d0_row5_col7" class="data row5 col7" >170</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_669d0_row6_col0" class="data row6 col0" >CH Gayle</td>
#       <td id="T_669d0_row6_col1" class="data row6 col1" >408</td>
#       <td id="T_669d0_row6_col2" class="data row6 col2" >359</td>
#       <td id="T_669d0_row6_col3" class="data row6 col3" >32</td>
#       <td id="T_669d0_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_669d0_row6_col5" class="data row6 col5" >175</td>
#       <td id="T_669d0_row6_col6" class="data row6 col6" >4997</td>
#       <td id="T_669d0_row6_col7" class="data row6 col7" >141</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_669d0_row7_col0" class="data row7 col0" >MS Dhoni</td>
#       <td id="T_669d0_row7_col1" class="data row7 col1" >346</td>
#       <td id="T_669d0_row7_col2" class="data row7 col2" >229</td>
#       <td id="T_669d0_row7_col3" class="data row7 col3" >24</td>
#       <td id="T_669d0_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_669d0_row7_col5" class="data row7 col5" >84</td>
#       <td id="T_669d0_row7_col6" class="data row7 col6" >4978</td>
#       <td id="T_669d0_row7_col7" class="data row7 col7" >205</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_669d0_row8_col0" class="data row8 col0" >RV Uthappa</td>
#       <td id="T_669d0_row8_col1" class="data row8 col1" >481</td>
#       <td id="T_669d0_row8_col2" class="data row8 col2" >182</td>
#       <td id="T_669d0_row8_col3" class="data row8 col3" >27</td>
#       <td id="T_669d0_row8_col4" class="data row8 col4" >0</td>
#       <td id="T_669d0_row8_col5" class="data row8 col5" >88</td>
#       <td id="T_669d0_row8_col6" class="data row8 col6" >4954</td>
#       <td id="T_669d0_row8_col7" class="data row8 col7" >197</td>
#     </tr>
#     <tr>
#       <th id="T_669d0_level0_row9" class="row

# %% [markdown]
# <a id="4.2.3"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Top 10 Batsmen Run Details</div>

# %%
# top_batsman_score

fig = make_subplots(cols=2,rows=3,
    vertical_spacing = 0.25, horizontal_spacing=.1,
                    subplot_titles=["No. of Sixers","No. of Fours",
                                    "No. of Half-Centuries","No. of Centuries",
                                   "Highest Scores", "Total Runs"],
                    y_title="<b>Top 10 Batsmen Run Details</b>"
    )
fig.add_trace(go.Bar(x=top_batsman_score.batsman,y=top_batsman_score.sixers,name="Highest Sixers"),row=1,col=1)
fig.add_trace(go.Bar(x=top_batsman_score.batsman,y=top_batsman_score.fours,name="Highest Fours"),row=1,col=2)
fig.add_trace(go.Bar(x=top_batsman_score.batsman,y=top_batsman_score.fifties,name="Highest Fifties"),row=2,col=1)
fig.add_trace(go.Bar(x=top_batsman_score.batsman,y=top_batsman_score.hundreds,name="Highest Hundreds"),row=2,col=2)
fig.add_trace(go.Bar(x=top_batsman_score.batsman,y=top_batsman_score.heighest_score,name="Highest Score"),row=3,col=1)
fig.add_trace(go.Bar(x=top_batsman_score.batsman,y=top_batsman_score.total_runs,name="Total Runs"),row=3,col=2)
fig.update_layout(height=800,width=1000, title_text="<b>Top 10 Batsmen Performance</b>",
                  title_font_family="Times New Roman",title_font_color="red",
                  title_font_size=20,)
fig.show()
# Out:
# <div>                            <div id="ac4d18f1-4741-4839-83b6-681426c7e2e1" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac4d18f1-4741-4839-83b6-681426c7e2e1")) {                    Plotly.newPlot(                        "ac4d18f1-4741-4839-83b6-681426c7e2e1",                        [{"name":"Highest Sixers","x":["V Kohli","S Dhawan","DA Warner","RG Sharma","SK Raina","AB de Villiers","CH Gayle","MS Dhoni","RV Uthappa","KD Karthik"],"y":[219,137,216,241,204,253,359,229,182,134],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Highest Fours","x":["V Kohli","S Dhawan","DA Warner","RG Sharma","SK Raina","AB de Villiers","CH Gayle","MS Dhoni","RV Uthappa","KD Karthik"],"y":[581,701,577,519,506,414,408,346,481,426],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Highest Fifties","x":["V Kohli","S Dhawan","DA Warner","RG Sharma","SK Raina","AB de Villiers","CH Gayle","MS Dhoni","RV Uthappa","KD Karthik"],"y":[45,47,55,40,39,41,32,24,27,20],"type":"bar","xaxis":"x3","yaxis":"y3"},{"name":"Highest Hundreds","x":["V Kohli","S Dhawan","DA Warner","RG Sharma","SK Raina","AB de Villiers","CH Gayle","MS Dhoni","RV Uthappa","KD Karthik"],"y":[5,2,4,1,1,3,6,0,0,0],"type":"bar","xaxis":"x4","yaxis":"y4"},{"name":"Highest Score","x":["V Kohli","S Dhawan","DA Warner","RG Sharma","SK Raina","AB de Villiers","CH Gayle","MS Dhoni","RV Uthappa","KD Karthik"],"y":[113,106,126,109,100,133,175,84,88,97],"type":"bar","xaxis":"x5","yaxis":"y5"},{"name":"Total Runs","x":["V Kohli","S Dhawan","DA Warner","RG Sharma","SK Raina","AB de Villiers","CH Gayle","MS Dhoni","RV Uthappa","KD Karthik"],"y":[6634,6244,5883,5881,5536,5181,4997,4978,4954,4377],"type":"bar","xaxis":"x6","yaxis":"y6"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0 ...

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     Highest number of runs were scored by <b>V Kohli (6634)</b> followed by <b>S Dhawan (6244)</b> and <b>DA Warner (5883)</b>.</div>

# %% [markdown]
# <a id="4.2.4"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Highest 6s hitters in IPL</div>

# %%
highest_sixers = ball_data[ball_data['batsman_run']==6].groupby('batter').agg(six_count=('batsman_run', 'count'))\
      .reset_index().sort_values(by='six_count', ascending=False).head(10)

fig = go.Figure(data=px.bar(x=highest_sixers.batter, 
                            y=highest_sixers.six_count,
                            color = highest_sixers.six_count,
                            color_discrete_sequence=px.colors.sequential.Oranges,
                            title='<b>Top 10 Six-hitters in IPL</b>',
                            text = highest_sixers.six_count,
                            height=400))

fig.update_layout(
    font_family="Courier New",
    title_font_family="Times New Roman",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Batsman</b>",
    yaxis_title="<b>No. of Sixers</b>",
    legend_title_font_color="green"
)

fig.show()
# Out:
# <div>                            <div id="30886e98-ad09-4703-b7f2-f46079e138ea" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30886e98-ad09-4703-b7f2-f46079e138ea")) {                    Plotly.newPlot(                        "30886e98-ad09-4703-b7f2-f46079e138ea",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>text=%{text}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[359,253,241,229,224,219,216,204,190,182],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[359.0,253.0,241.0,229.0,224.0,219.0,216.0,204.0,190.0,182.0],"textposition":"auto","x":["CH Gayle","AB de Villiers","RG Sharma","MS Dhoni","KA Pollard","V Kohli","DA Warner","SK Raina","SR Watson","RV Uthappa"],"xaxis":"x","y":[359,253,241,229,224,219,216,204,190,182],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"height":400,"legend":{"tracegroupgap":0,"title":{"font":{"color":"green"}}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111111111 ...

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     <b>CH Gayle</b> scored highest number of sixers <b>(359)</b> followed by <b>AB de Villiers(253)</b> and <b>  RG Sharma (241)</b>.</div>

# %% [markdown]
# <a id="4.2.5"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Highest 4s hitters in IPL</div>

# %%
highest_fours = ball_data[ball_data['batsman_run']==4].groupby('batter').agg(four_count=('batsman_run', 'count'))\
      .reset_index().sort_values(by='four_count', ascending=False).head(10)
# highest_fours
fig = go.Figure(data=px.bar(x=highest_fours.batter, 
                            y=highest_fours.four_count,
                            color = highest_fours.four_count,
                            color_discrete_sequence=px.colors.sequential.Oranges,
                            title='<b>Top 10 Four-hitters in IPL</b>',
                            text = highest_fours.four_count,
                            height=400))
fig.update_layout(
    font_family="Courier New",
    title_font_family="Times New Roman",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Batsman</b>",
    yaxis_title="<b>No. of Fours</b>",
    legend_title_font_color="green"
)

fig.show()
# Out:
# <div>                            <div id="4318cf89-24ef-49bd-ac49-6f50eb90af57" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4318cf89-24ef-49bd-ac49-6f50eb90af57")) {                    Plotly.newPlot(                        "4318cf89-24ef-49bd-ac49-6f50eb90af57",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>text=%{text}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[701,581,577,519,506,492,481,431,426,414],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[701.0,581.0,577.0,519.0,506.0,492.0,481.0,431.0,426.0,414.0],"textposition":"auto","x":["S Dhawan","V Kohli","DA Warner","RG Sharma","SK Raina","G Gambhir","RV Uthappa","AM Rahane","KD Karthik","AB de Villiers"],"xaxis":"x","y":[701,581,577,519,506,492,481,431,426,414],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"height":400,"legend":{"tracegroupgap":0,"title":{"font":{"color":"green"}}},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111 ...

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     <b>S Dhawan</b> scored highest number of fours <b>(701)</b> followed by <b>V Kohli (581)</b> and <b>DA Warner(577)</b> .</div>

# %% [markdown]
# <a id="4.2.6"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Sixer data - Team wise</div>

# %%
sixer_df=ball_data['battingteam'][(ball_data['batsman_run']==6) & (ball_data['season']=='2022')].reset_index()
sixer_df=sixer_df.groupby('battingteam').agg(sixer_count=('battingteam','count')).reset_index()
sixer_df=sixer_df.sort_values('sixer_count', ascending=False)

fig = plt.figure(figsize =(10, 7))
plt.pie(sixer_df['sixer_count'], labels = sixer_df['battingteam'], autopct='%0.1f%%')
plt.title("Team wise Sixer Data", fontsize=20, color='red', fontweight='bold')
plt.show()

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     <b>Rajasthan Royals</b> scored highest number of sixers<b>(12.9%)</b>.</div>

# %% [markdown]
# <a id="4.2.7"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Top batsmen score against opponent teams</div>

# %%
df1 = ball_data[['batter','bowlingteam', 'batsman_run']][ball_data['batter'].isin(top_batsman['batter'])]\
            .groupby(['batter', 'bowlingteam']).agg(batter_score=('batsman_run', 'sum')).reset_index()

print(Back.GREEN+ Style.BRIGHT+'Runs scored by top batsmen against opponent teams'+ Style.RESET_ALL)
df2 = df1.pivot_table('batter_score', ['bowlingteam'], 'batter')
df2.style.background_gradient(axis=None, low=0.75, high=1.0)
# Out:
# Runs scored by top batsmen against opponent teams
# <style type="text/css">
# #T_119c0_row0_col0, #T_119c0_row17_col6 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_119c0_row0_col1 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_119c0_row0_col2, #T_119c0_row6_col3 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_119c0_row0_col3, #T_119c0_row13_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_119c0_row0_col4, #T_119c0_row0_col8, #T_119c0_row4_col3, #T_119c0_row4_col8, #T_119c0_row5_col0, #T_119c0_row5_col1, #T_119c0_row5_col2, #T_119c0_row5_col8, #T_119c0_row7_col5, #T_119c0_row9_col0, #T_119c0_row9_col1, #T_119c0_row9_col8, #T_119c0_row11_col6, #T_119c0_row12_col1, #T_119c0_row14_col1, #T_119c0_row14_col4, #T_119c0_row15_col1, #T_119c0_row15_col4, #T_119c0_row16_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_119c0_row0_col5, #T_119c0_row10_col9 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_119c0_row0_col6, #T_119c0_row8_col4, #T_119c0_row13_col1 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_119c0_row0_col7, #T_119c0_row8_col5 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_119c0_row0_col9 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_119c0_row1_col0, #T_119c0_row2_col3, #T_119c0_row2_col6, #T_119c0_row2_col8, #T_119c0_row11_col0 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_119c0_row1_col1, #T_119c0_row7_col3, #T_119c0_row7_col8, #T_119c0_row12_col3 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_119c0_row1_col2, #T_119c0_row4_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_119c0_row1_col3, #T_119c0_row2_col4, #T_119c0_row2_col9, #T_119c0_row12_col7 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_119c0_row1_col4, #T_119c0_row4_col9, #T_119c0_row8_col6 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_119c0_row1_col5, #T_119c0_row2_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_119c0_row1_col6, #T_119c0_row11_col3 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_119c0_row1_col7, #T_119c0_row2_col1, #T_119c0_row11_col2, #T_119c0_row12_col9 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_119c0_row1_col8, #T_119c0_row1_col9, #T_119c0_row16_col1 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_119c0_row2_col2, #T_119c0_row15_col9 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_119c0_row2_col5 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_119c0_row2_col7, #T_119c0_row7_col6, #T_119c0_row14_col0, #T_119c0_row14_col3, #T_119c0_row15_col3 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_119c0_row3_col0 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_119c0_row3_col1, #T_119c0_row11_col1, #T_119c0_row13_col6 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_119c0_row3_col2, #T_119c0_row17_col7 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_119c0_row3_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_119c0_row3_col4, #T_119c0_row17_col4 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_119c0_row3_col5, #T_119c0_row6_col0, #T_119c0_row8_col1, #T_119c0_row16_col8 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_119c0_row3_col6 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_119c0_row3_col7, #T_119c0_row8_col0, #T_119c0_row13_col4 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_119c0_row3_col8 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_119c0_row3_col9, #T_119c0_row6_col6 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_119c0_row4_col1, #T_119c0_row5_col7, #T_119c0_row10_col5, #T_119c0_row12_col2, #T_119c0_row12_col5, #T_119c0_row17_col2 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_119c0_row4_col2, #T_119c0_row10_col3 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_119c0_row4_col4, #T_119c0_row14_col2, #T_119c0_row14_col5, #T_119c0_row14_col6, #T_119c0_row14_col9, #T_119c0_row15_col0, #T_119c0_row15_col5, #T_119c0_row15_col7 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_119c0_row4_col5, #T_119c0_row11_col7 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_119c0_row4_col6, #T_119c0_row16_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_119c0_row4_col7, #T_119c0_row5_col9, #T_119c0_row11_col4, #T_119c0_row11_col5, #T_119c0_row11_col8, #T_119c0_row11_col9 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_119c0_row5_col3, #T_119c0_row5_col6, #T_119c0_row7_col7, #T_119c0_row9_col7, #T_119c0_row15_col6 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_119c0_row5_col4, #T_119c0_row7_col2, #T_119c0_row9_col2, #T_119c0_row9_col4, #T_119c0_row12_col6, #T_119c0_row12_col8, #T_119c0_row15_col2 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_119c0_row5_col5, #T_119c0_row7_col1, #T_119c0_row9_col5, #T_119c0_row12_col4, #T_119c0_row14_col7, #T_119c0_row14_col8 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_119c0_row6_col1, #T_119c0_row10_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_119c0_row6_col2 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_119c0_row6_col4, #T_119c0_row10_col6, #T_119c0_row13_col9 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_119c0_row6_col5 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_119c0_row6_col7 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_119c0_row6_col8, #T_119c0_row8_col8, #T_119c0_row10_col8 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_119c0_row6_col9, #T_119c0_row16_col6, #T_119c0_row16_col7 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_119c0_row7_col0, #T_119c0_row7_col9, #T_119c0_row9_col3, #T_119c0_row9_col6, #T_119c0_row15_col8 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_119c0_row7_col4, #T_119c0_row9_col9, #T_119c0_row12_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_119c0_row8_col2 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_119c0_row8_col3 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_119c0_row8_col7, #T_119c0_row16_col2 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_119c0_row8_col9, #T_119c0_row16_col5 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_119c0_row10_col1 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_119c0_row10_col2 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_119c0_row10_col4 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_119c0_row10_col7 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_119c0_row13_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_119c0_row13_col3 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_119c0_row13_col5, #T_119c0_row17_col0 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_119c0_row13_col7, #T_119c0_row17_col9 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_119c0_row13_col8 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_119c0_row16_col3, #T_119c0_row17_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_119c0_row16_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_119c0_row17_col3, #T_119c0_row17_col5 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_119c0_row17_col8 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# </style>
# <table id="T_119c0_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >batter</th>
#       <th class="col_heading level0 col0" >AB de Villiers</th>
#       <th class="col_heading level0 col1" >CH Gayle</th>
#       <th class="col_heading level0 col2" >DA Warner</th>
#       <th class="col_heading level0 col3" >KD Karthik</th>
#       <th class="col_heading level0 col4" >MS Dhoni</th>
#       <th class="col_heading level0 col5" >RG Sharma</th>
#       <th class="col_heading level0 col6" >RV Uthappa</th>
#       <th class="col_heading level0 col7" >S Dhawan</th>
#       <th class="col_heading level0 col8" >SK Raina</th>
#       <th class="col_heading level0 col9" >V Kohli</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >bowlingteam</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nb

# %% [markdown]
# <a id="4.2.8"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🖼️Plot for selected batsmen across seasons</div>

# %%
top_batsman =['RG Sharma', 'S Dhawan', 'SK Raina', 'V Kohli'] 
top_batsman_runs=ball_data[ball_data['batter'].isin(top_batsman)].groupby(['season','batter'])\
    .agg(batsman_total=('batsman_run', 'sum')).reset_index()\
    .sort_values(by=['season','batsman_total'], ascending=False)

fig = px.line(top_batsman_runs, x='season', y='batsman_total', color='batter', symbol="batter",template='simple_white')
fig.update_layout(hovermode="x unified")
fig.update_xaxes(categoryorder='category ascending')
fig.update_yaxes(showgrid=True)
fig.update_traces(line=dict(width=3.0))

fig.update_layout(
    title='<b>Batter Performance across seasons</b>',
    font_family="Courier New",
    title_font_family="Courier New",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Season</b>",
    yaxis_title="<b>Runs</b>",
    legend_title='<b>Batter</b>',
    legend_title_font_color="red",
    plot_bgcolor = '#FFFFFF'
)

fig.show()
# Out:
# <div>                            <div id="0d0c428b-5d03-4e37-aa76-3b91692016ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d0c428b-5d03-4e37-aa76-3b91692016ce")) {                    Plotly.newPlot(                        "0d0c428b-5d03-4e37-aa76-3b91692016ce",                        [{"hovertemplate":"batter=S Dhawan<br>season=%{x}<br>batsman_total=%{y}<extra></extra>","legendgroup":"S Dhawan","line":{"color":"#1F77B4","dash":"solid","width":3.0},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"S Dhawan","orientation":"v","showlegend":true,"x":["2022","2021","2020/21","2019","2018","2017","2016","2015","2014","2013","2012","2011","2009/10","2009","2007/08"],"xaxis":"x","y":[460,587,618,521,497,479,501,353,377,311,569,400,191,40,340],"yaxis":"y","type":"scatter"},{"hovertemplate":"batter=V Kohli<br>season=%{x}<br>batsman_total=%{y}<extra></extra>","legendgroup":"V Kohli","line":{"color":"#FF7F0E","dash":"solid","width":3.0},"marker":{"symbol":"diamond"},"mode":"markers+lines","name":"V Kohli","orientation":"v","showlegend":true,"x":["2022","2021","2020/21","2019","2018","2017","2016","2015","2014","2013","2012","2011","2009/10","2009","2007/08"],"xaxis":"x","y":[341,405,471,464,530,308,973,505,359,639,364,557,307,246,165],"yaxis":"y","type":"scatter"},{"hovertemplate":"batter=RG Sharma<br>season=%{x}<br>batsman_total=%{y}<extra></extra>","legendgroup":"RG Sharma","line":{"color":"#2CA02C","dash":"solid","width":3.0},"marker":{"symbol":"square"},"mode":"markers+lines","name":"RG Sharma","orientation":"v","showlegend":true,"x":["2022","2021","2020/21","2019","2018","2017","2016","2015","2014","2013","2012","2011","2009/10","2009","2007/08"],"xaxis":"x","y":[268,381,334,405,286,333,489,482,390,538,433,372,404,362,404],"yaxis":"y","type":"scatter"},{"hovertemplate":"batter=SK Raina<br>season=%{x}<br>batsman_total=%{y}<extra></extra>","legendgroup":"SK Raina","line":{"color":"#D62728","dash":"solid","width":3.0},"marker":{"symbol":"x"},"mode":"markers+lines","name":"SK Raina","orientation":"v","showlegend":true,"x":["2021","2019","2018","2017","2016","2015","2014","2013","2012","2011","2009/10","2009","2007/08"],"xaxis":"x","y":[160,383,445,442,399,374,523,548,441,438,528,434,421],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222," ...

# %% [markdown]
# <a id="4.3"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> ⛹Bowler Performance Analysis</div>

# %% [markdown]
# <a id="4.3.1"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🎛️Top 10 wicket takers</div>

# %%
print(Back.GREEN+ Style.BRIGHT+'Top 10 wicket takers'+ Style.RESET_ALL)
dismissal_list = ['caught','caught and bowled','bowled','stumped','hit wicket']
top10_bowlers=ball_data[(ball_data['is_wicket']==1) & (ball_data['dismissal_kind'].isin(dismissal_list))]\
                            .groupby('bowler').agg(wicket_count=('is_wicket', 'count'))\
                            .sort_values('wicket_count', ascending=False).reset_index().head(10)
top10_bowlers.style.background_gradient("Blues")
# Out:
# Top 10 wicket takers
# <style type="text/css">
# #T_ee376_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ee376_row1_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_ee376_row2_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_ee376_row3_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_ee376_row4_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_ee376_row5_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_ee376_row6_col1, #T_ee376_row7_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_ee376_row8_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ee376_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_ee376_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >bowler</th>
#       <th class="col_heading level0 col1" >wicket_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee376_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee376_row0_col0" class="data row0 col0" >DJ Bravo</td>
#       <td id="T_ee376_row0_col1" class="data row0 col1" >175</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ee376_row1_col0" class="data row1 col0" >SL Malinga</td>
#       <td id="T_ee376_row1_col1" class="data row1 col1" >159</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ee376_row2_col0" class="data row2 col0" >YS Chahal</td>
#       <td id="T_ee376_row2_col1" class="data row2 col1" >153</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ee376_row3_col0" class="data row3 col0" >A Mishra</td>
#       <td id="T_ee376_row3_col1" class="data row3 col1" >152</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ee376_row4_col0" class="data row4 col0" >B Kumar</td>
#       <td id="T_ee376_row4_col1" class="data row4 col1" >145</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ee376_row5_col0" class="data row5 col0" >Harbhajan Singh</td>
#       <td id="T_ee376_row5_col1" class="data row5 col1" >142</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ee376_row6_col0" class="data row6 col0" >PP Chawla</td>
#       <td id="T_ee376_row6_col1" class="data row6 col1" >140</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ee376_row7_col0" class="data row7 col0" >R Ashwin</td>
#       <td id="T_ee376_row7_col1" class="data row7 col1" >140</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ee376_row8_col0" class="data row8 col0" >JJ Bumrah</td>
#       <td id="T_ee376_row8_col1" class="data row8 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_ee376_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ee376_row9_col0" class="data row9 col0" >SP Narine</td>
#       <td id="T_ee376_row9_col1" class="data row9 col1" >130</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     <b>DJ Bravo</b> is the highest wicket taker with <b>175</b> wickets, followed by <b>SL Malinga (159)</b> and <b>YS Chahal (153)</b>.</div>

# %% [markdown]
# <a id="4.3.2"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🎛️Wicket count against opponent teams</div>

# %%
print(Back.GREEN+ Style.BRIGHT+'Bowler performance(wicket count) against opponent teams'+ Style.RESET_ALL)
bowler_team = ball_data[(ball_data['is_wicket']==1) & (ball_data['dismissal_kind'].isin(dismissal_list))\
                            & (ball_data['bowler'].isin(top10_bowlers['bowler']))]\
                            .groupby(['bowler','battingteam']).agg(wkt_count=('is_wicket', 'count'))\
                            .reset_index()

bowler_team = bowler_team.pivot_table('wkt_count', ['battingteam'], 'bowler')
bowler_team.style.background_gradient("Blues")
# Out:
# Bowler performance(wicket count) against opponent teams
# <style type="text/css">
# #T_461c2_row0_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_461c2_row0_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_461c2_row0_col2, #T_461c2_row11_col2, #T_461c2_row11_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_461c2_row0_col3 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_461c2_row0_col4, #T_461c2_row13_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_461c2_row0_col5 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_461c2_row0_col6 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_461c2_row0_col7, #T_461c2_row6_col8, #T_461c2_row8_col1, #T_461c2_row10_col2, #T_461c2_row10_col5, #T_461c2_row10_col6, #T_461c2_row10_col9, #T_461c2_row13_col0, #T_461c2_row16_col3, #T_461c2_row16_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_461c2_row0_col8, #T_461c2_row2_col4 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_461c2_row0_col9, #T_461c2_row13_col4 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_461c2_row1_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_461c2_row1_col1, #T_461c2_row5_col1, #T_461c2_row15_col1, #T_461c2_row15_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_461c2_row1_col2, #T_461c2_row4_col4 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_461c2_row1_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_461c2_row1_col4, #T_461c2_row1_col9, #T_461c2_row2_col0, #T_461c2_row4_col2, #T_461c2_row4_col6, #T_461c2_row4_col8, #T_461c2_row5_col0, #T_461c2_row5_col3, #T_461c2_row5_col4, #T_461c2_row5_col5, #T_461c2_row5_col6, #T_461c2_row5_col7, #T_461c2_row5_col8, #T_461c2_row7_col1, #T_461c2_row7_col3, #T_461c2_row7_col4, #T_461c2_row7_col5, #T_461c2_row7_col8, #T_461c2_row7_col9, #T_461c2_row8_col8, #T_461c2_row9_col0, #T_461c2_row9_col1, #T_461c2_row9_col3, #T_461c2_row9_col5, #T_461c2_row9_col7, #T_461c2_row10_col4, #T_461c2_row10_col7, #T_461c2_row11_col1, #T_461c2_row11_col4, #T_461c2_row11_col9, #T_461c2_row12_col0, #T_461c2_row12_col3, #T_461c2_row12_col5, #T_461c2_row12_col7, #T_461c2_row14_col2, #T_461c2_row14_col6, #T_461c2_row14_col9, #T_461c2_row15_col6, #T_461c2_row15_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_461c2_row1_col5 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_461c2_row1_col6, #T_461c2_row11_col6 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_461c2_row1_col7, #T_461c2_row3_col7 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_461c2_row1_col8, #T_461c2_row2_col8, #T_461c2_row14_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_461c2_row2_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_461c2_row2_col2, #T_461c2_row3_col2, #T_461c2_row13_col7 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_461c2_row2_col3, #T_461c2_row4_col3 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_461c2_row2_col5, #T_461c2_row4_col5, #T_461c2_row5_col9, #T_461c2_row10_col3, #T_461c2_row11_col5, #T_461c2_row12_col4, #T_461c2_row14_col4, #T_461c2_row15_col3, #T_461c2_row15_col5, #T_461c2_row16_col9 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_461c2_row2_col6, #T_461c2_row7_col6 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_461c2_row2_col7, #T_461c2_row7_col0, #T_461c2_row7_col2, #T_461c2_row9_col2, #T_461c2_row9_col4, #T_461c2_row9_col6, #T_461c2_row9_col8, #T_461c2_row12_col6, #T_461c2_row14_col1, #T_461c2_row14_col3, #T_461c2_row14_col5, #T_461c2_row14_col7, #T_461c2_row15_col0, #T_461c2_row15_col8, #T_461c2_row15_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_461c2_row2_col9, #T_461c2_row9_col9 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_461c2_row3_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_461c2_row3_col1, #T_461c2_row12_col1 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_461c2_row3_col3, #T_461c2_row6_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_461c2_row3_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_461c2_row3_col5 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_461c2_row3_col6 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_461c2_row3_col8, #T_461c2_row3_col9 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_461c2_row4_col0, #T_461c2_row7_col7 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_461c2_row4_col1, #T_461c2_row17_col6 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_461c2_row4_col7, #T_461c2_row14_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_461c2_row4_col9 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_461c2_row5_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_461c2_row6_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_461c2_row6_col1, #T_461c2_row10_col1 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_461c2_row6_col2, #T_461c2_row8_col2, #T_461c2_row8_col3, #T_461c2_row16_col5, #T_461c2_row17_col2 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_461c2_row6_col4, #T_461c2_row8_col4 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_461c2_row6_col5 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_461c2_row6_col6 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_461c2_row6_col7, #T_461c2_row8_col7 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_461c2_row6_col9, #T_461c2_row8_col9 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_461c2_row8_col0, #T_461c2_row16_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_461c2_row8_col5 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_461c2_row8_col6 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_461c2_row10_col0, #T_461c2_row17_col4 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_461c2_row10_col8 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_461c2_row11_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_461c2_row11_col7 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_461c2_row11_col8 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_461c2_row12_col2, #T_461c2_row15_col4 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_461c2_row12_col8 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_461c2_row12_col9 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_461c2_row13_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_461c2_row13_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_461c2_row13_col5 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_461c2_row13_col6 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_461c2_row13_col8, #T_461c2_row17_col3, #T_461c2_row17_col5 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_461c2_row13_col9 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_461c2_row16_col1, #T_461c2_row16_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_461c2_row16_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_461c2_row16_col6 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_461c2_row16_col8 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_461c2_row17_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_461c2_row17_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_461c2_row17_col7 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_461c2_row17_col8 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_461c2_row17_col9 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_461c2_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >bowler</th>
#       <th class="col_heading level0 col0" >A Mishra</th>
#       <th class="col_heading level0 col1" >B Kumar</th>
#       <th class="col_heading level0 col2" >DJ Bravo</th>
#       <th class="col_heading level0 col3" >Harbhajan Singh</th>
#       <th class="col_heading level0 col4" >JJ Bumrah</th>
#       <th class="col_heading level0 col5" >PP Chawla</th>
#       <th class="col_heading level0 col6" >R Ashwin</th>
#       <th class="col_heading level0 col7" >SL Malinga</th>
#       <th class="col_heading level0 col8" >SP Narine</th>
#       <th class="col_heading level0 col9" >YS Chahal</th>
#     </tr>
#     <

# %% [markdown]
# <a id="4.3.3"></a>
# #### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🎛️Hattriks in IPL</div>

# %%
#Let us list the Hattricks scored in IPL so far
wkt_bowlers= ball_data[ball_data['is_wicket']==1].groupby(['id','bowler']).agg(wkt_count=('is_wicket', 'count')).reset_index()
hattricks = pd.DataFrame(columns= ['bowler'])
for bow_index, bow_row in wkt_bowlers[wkt_bowlers['wkt_count']>=3][['id','bowler']].iterrows():
    wkt_cnt=0
    for ball_index, ball_row in ball_data[(ball_data['id']==bow_row['id']) &
                                          (ball_data['bowler']==bow_row['bowler'])]\
                                            .sort_values(by =(['id','inning','over','ballnumber'])).iterrows():

        if ball_row['is_wicket']==1 and ball_row['dismissal_kind'] not in ['run out','retired hurt','obstructing the field'] :
            wkt_cnt +=1
            if wkt_cnt == 3: 
                wkt_cnt = 0
                hattricks = hattricks.append({'bowler' : ball_row['bowler']}, ignore_index = True)
        else:wkt_cnt =0
            
hattricks = hattricks.groupby('bowler').agg(hatk_count=('bowler', 'count')).reset_index()
# hattricks

fig = go.Figure(data=px.bar(x=hattricks.bowler, 
                            y=hattricks.hatk_count,
                            color = hattricks.bowler,
                            color_discrete_sequence=px.colors.sequential.Plasma,
                            title='<b>Hattricks in IPL</b>',
                            text = hattricks.hatk_count,
                            height=500))
fig.update_layout(
    font_family="Courier New",
    title_font_family="Times New Roman",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Bowler</b>",
    yaxis_title="<b>Hattricks</b>",
    legend_title_font_color="green"
)

fig.show()
# Out:
# <div>                            <div id="acec59b0-db89-4ed1-89b7-8b41cc52f21c" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("acec59b0-db89-4ed1-89b7-8b41cc52f21c")) {                    Plotly.newPlot(                        "acec59b0-db89-4ed1-89b7-8b41cc52f21c",                        [{"alignmentgroup":"True","hovertemplate":"color=A Chandila<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"A Chandila","marker":{"color":"#0d0887","pattern":{"shape":""}},"name":"A Chandila","offsetgroup":"A Chandila","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["A Chandila"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=A Mishra<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"A Mishra","marker":{"color":"#46039f","pattern":{"shape":""}},"name":"A Mishra","offsetgroup":"A Mishra","orientation":"v","showlegend":true,"text":[3.0],"textposition":"auto","x":["A Mishra"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AJ Tye<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"AJ Tye","marker":{"color":"#7201a8","pattern":{"shape":""}},"name":"AJ Tye","offsetgroup":"AJ Tye","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["AJ Tye"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AR Patel<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"AR Patel","marker":{"color":"#9c179e","pattern":{"shape":""}},"name":"AR Patel","offsetgroup":"AR Patel","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["AR Patel"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=HV Patel<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"HV Patel","marker":{"color":"#bd3786","pattern":{"shape":""}},"name":"HV Patel","offsetgroup":"HV Patel","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["HV Patel"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=JD Unadkat<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"JD Unadkat","marker":{"color":"#d8576b","pattern":{"shape":""}},"name":"JD Unadkat","offsetgroup":"JD Unadkat","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["JD Unadkat"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=L Balaji<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"L Balaji","marker":{"color":"#ed7953","pattern":{"shape":""}},"name":"L Balaji","offsetgroup":"L Balaji","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["L Balaji"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=M Ntini<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"M Ntini","marker":{"color":"#fb9f3a","pattern":{"shape":""}},"name":"M Ntini","offsetgroup":"M Ntini","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["M Ntini"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=P Kumar<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"P Kumar","marker":{"color":"#fdca26","pattern":{"shape":""}},"name":"P Kumar","offsetgroup":"P Kumar","orientation":"v","showlegend":true,"text":[1.0],"textposition":"auto","x":["P Kumar"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=PV Tambe<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"PV Tambe","marker":{"color":"#f0f921","pattern":{"shape":""}},"name":"PV Tambe ...

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     From the above data we can see <b>Amit Mishra(3 times)</b> and <b>Yuvraj Singh(2 times)</b> scoring hattricks more than once.</div>

# %% [markdown]
# <a id="4.4"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 😊Player of the match Data Analysis</div>

# %%
pom_df=match_data.groupby(['season','player_of_match']).agg(pom_count=('player_of_match','count')).reset_index()
pom_df


pom_df['Rank'] = pom_df.groupby('season')['pom_count'].rank(ascending=False)
season_top_pom=pom_df[pom_df['Rank']==1].sort_values('season')
#season_top_pom

fig = go.Figure(data=px.bar(x=season_top_pom.season, 
                            y=season_top_pom.pom_count,
                            color = season_top_pom.player_of_match,
                            color_discrete_sequence=colorsy,
                            title='<b>Top 10 Player-of-the-Match winners in IPL</b>',
                            text = season_top_pom.pom_count,
                            height=500))

fig.update_layout(
    font_family="Courier New",
    title_font_family="Times New Roman",
    title_font_color="red",
    title_font_size=20,
    xaxis_title="<b>Season</b>",
    yaxis_title="<b>No. of PoMs</b>",
    legend_title_font_color="green"
)

fig.show()
# Out:
# <div>                            <div id="54e91bd1-2e52-4b4f-a752-5905d7f713b4" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54e91bd1-2e52-4b4f-a752-5905d7f713b4")) {                    Plotly.newPlot(                        "54e91bd1-2e52-4b4f-a752-5905d7f713b4",                        [{"alignmentgroup":"True","hovertemplate":"color=SE Marsh<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"SE Marsh","marker":{"color":"#0d293f","pattern":{"shape":""}},"name":"SE Marsh","offsetgroup":"SE Marsh","orientation":"v","showlegend":true,"text":[5.0],"textposition":"auto","x":["2007/08"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=YK Pathan<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"YK Pathan","marker":{"color":"#1f4956","pattern":{"shape":""}},"name":"YK Pathan","offsetgroup":"YK Pathan","orientation":"v","showlegend":true,"text":[3.0],"textposition":"auto","x":["2009"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=SR Tendulkar<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"SR Tendulkar","marker":{"color":"#185175","pattern":{"shape":""}},"name":"SR Tendulkar","offsetgroup":"SR Tendulkar","orientation":"v","showlegend":true,"text":[4.0],"textposition":"auto","x":["2009/10"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=CH Gayle<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"CH Gayle","marker":{"color":"#19618f","pattern":{"shape":""}},"name":"CH Gayle","offsetgroup":"CH Gayle","orientation":"v","showlegend":true,"text":[6.0,5.0],"textposition":"auto","x":["2011","2012"],"xaxis":"x","y":[6,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=MEK Hussey<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"MEK Hussey","marker":{"color":"#43779a","pattern":{"shape":""}},"name":"MEK Hussey","offsetgroup":"MEK Hussey","orientation":"v","showlegend":true,"text":[5.0],"textposition":"auto","x":["2013"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=GJ Maxwell<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"GJ Maxwell","marker":{"color":"#147eb0","pattern":{"shape":""}},"name":"GJ Maxwell","offsetgroup":"GJ Maxwell","orientation":"v","showlegend":true,"text":[4.0],"textposition":"auto","x":["2014"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=DA Warner<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"DA Warner","marker":{"color":"#2d93ca","pattern":{"shape":""}},"name":"DA Warner","offsetgroup":"DA Warner","orientation":"v","showlegend":true,"text":[4.0],"textposition":"auto","x":["2015"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=V Kohli<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"V Kohli","marker":{"color":"#58a9db","pattern":{"shape":""}},"name":"V Kohli","offsetgroup":"V Kohli","orientation":"v","showlegend":true,"text":[5.0],"textposition":"auto","x":["2016"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Rashid Khan<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Rashid Khan","marker":{"color":"#8ab5d8","pattern":{"shape":""}},"name":"Rashid Khan","offsetgroup":"Rashid Khan","orientation":"v","showlegend":true,"text":[4.0],"textposition":"auto","x":["2018"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AD Russell<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"AD Russell","marker":{"color":"#9ccef0","patt ...

# %% [markdown]
# <a id="4.5"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🥇High scores successfully chased</div>

# %%
full_data = pd.merge(match_data, ball_data, how='left', on='id')

inning_data = full_data[['id', 'inning', 'total_runs']]\
                        [(full_data['superover']=='N') & (full_data['method'] !='D/L')]\
                        .groupby(['id', 'inning']).agg(inning_score=('total_runs','sum')).reset_index()
inning_data = inning_data.pivot_table('inning_score', ['id'], 'inning').reset_index()
inning_data.rename(columns = {1:'first_inning', 2:'second_inning'}, inplace=True)

match_scores = pd.merge(match_data, inning_data, how='left', on='id')

chased_matches=match_scores[match_scores['wonby']=='Wickets'].sort_values('first_inning', ascending=False)
defended_matches=match_scores[match_scores['wonby']=='Runs'].sort_values('first_inning', ascending=True)

print(Back.GREEN+ Style.BRIGHT+ 'Top 5 High scores successfully chased:' + Style.RESET_ALL)
for idx, row in chased_matches.head().iterrows():
    print(Fore.RED+ Style.BRIGHT+  row['team2'] + Style.RESET_ALL \
      + ' sucessfully chased target of ' \
      + Back.CYAN+ Style.BRIGHT+ Style.BRIGHT + str(row['first_inning']) + Style.RESET_ALL \
      + ' against '\
      + Fore.RED + Style.BRIGHT+ row['team1'] + Style.RESET_ALL
      + 'in season ' 
      + Fore.BLUE + Style.BRIGHT+ row['season'] + Style.RESET_ALL )
# Out:
# Top 5 High scores successfully chased:
# Rajasthan Royals sucessfully chased target of 223.0 against Kings XI Punjabin season 2020/21
# Mumbai Indians sucessfully chased target of 218.0 against Chennai Super Kingsin season 2021
# Rajasthan Royals sucessfully chased target of 214.0 against Deccan Chargersin season 2007/08
# Lucknow Super Giants sucessfully chased target of 210.0 against Chennai Super Kingsin season 2022
# Gujarat Lions sucessfully chased target of 208.0 against Delhi Daredevilsin season 2017

# %% [markdown]
# <a id="4.6"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🥇Low scores successfully defended</div>

# %%
print(Back.GREEN+ Style.BRIGHT+ 'Top 5 Low scores successfully defended:' + Style.RESET_ALL)
for idx, row in defended_matches.head().iterrows():
    print(Fore.RED+ Style.BRIGHT+  row['team1'] + Style.RESET_ALL \
      + ' sucessfully defended target of ' \
      + Back.CYAN + Style.BRIGHT+ str(row['first_inning']) + Style.RESET_ALL \
      + ' against '\
      + Fore.RED + Style.BRIGHT+ row['team2'] + Style.RESET_ALL
      + 'in season ' 
      + Fore.BLUE + Style.BRIGHT+ row['season'] + Style.RESET_ALL )
# Out:
# Top 5 Low scores successfully defended:
# Royal Challengers Bangalore sucessfully defended target of 106.0 against Chennai Super Kingsin season 2013
# Kings XI Punjab sucessfully defended target of 106.0 against Royal Challengers Bangalorein season 2015
# Chennai Super Kings sucessfully defended target of 116.0 against Kings XI Punjabin season 2009
# Sunrisers Hyderabad sucessfully defended target of 118.0 against Mumbai Indiansin season 2018
# Kings XI Punjab sucessfully defended target of 119.0 against Mumbai Indiansin season 2009

# %% [markdown]
# <a id="4.7"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🎮Win Margin Data Analysis</div>

# %%
print(Back.GREEN+ Style.BRIGHT+ 'Match win with highest run margin:' + Style.RESET_ALL)
for idx, row in match_data[['winningteam','win_against', 'margin', 'season']]\
    [match_data['margin'] == match_data['margin'].max()].iterrows():
    print(Fore.RED+ Style.BRIGHT+  row['winningteam'] + Style.RESET_ALL \
      + ' won with highest ever margin of ' \
      + Back.CYAN + Style.BRIGHT+ str(row['margin']) + Style.RESET_ALL \
      + ' against '\
      + Fore.RED + Style.BRIGHT+ row['win_against'] + Style.RESET_ALL
      + 'in season ' 
      + Fore.BLUE + Style.BRIGHT+ row['season'] + Style.RESET_ALL )
# Out:
# Match win with highest run margin:
# Mumbai Indians won with highest ever margin of 146.0 against Delhi Daredevilsin season 2017

# %%
print(Back.GREEN+ Style.BRIGHT+'Highest win margin in each season:'+ Style.RESET_ALL)
margin_df= match_data.groupby('season').agg(max_margin=('margin', 'max')).reset_index()
for idx1, row1 in margin_df[[ 'season', 'max_margin']].iterrows():
    for idx, row in match_data[['winningteam','win_against', 'margin', 'season']]\
            [(match_data['margin'] == row1['max_margin']) & (match_data['season'] == row1['season'])]\
            .iterrows():
        print(Fore.RED+ Style.BRIGHT+  row['winningteam'] + Style.RESET_ALL \
          + ' won with highest margin of ' \
          + Back.CYAN + Style.BRIGHT+ str(row['margin']) + Style.RESET_ALL \
          + ' against '\
          + Fore.RED + Style.BRIGHT+ row['win_against'] + Style.RESET_ALL
          + 'in season ' 
          + Fore.BLUE + Style.BRIGHT +row['season'] + Style.RESET_ALL )
# Out:
# Highest win margin in each season:
# Kolkata Knight Riders won with highest margin of 140.0 against Royal Challengers Bangalorein season 2007/08
# Mumbai Indians won with highest margin of 92.0 against Kolkata Knight Ridersin season 2009
# Chennai Super Kings won with highest margin of 92.0 against Royal Challengers Bangalorein season 2009
# Mumbai Indians won with highest margin of 98.0 against Delhi Daredevilsin season 2009/10
# Kings XI Punjab won with highest margin of 111.0 against Royal Challengers Bangalorein season 2011
# Chennai Super Kings won with highest margin of 86.0 against Delhi Daredevilsin season 2012
# Royal Challengers Bangalore won with highest margin of 130.0 against Pune Warriorsin season 2013
# Chennai Super Kings won with highest margin of 93.0 against Delhi Daredevilsin season 2014
# Royal Challengers Bangalore won with highest margin of 138.0 against Kings XI Punjabin season 2015
# Royal Challengers Bangalore won with highest margin of 144.0 against Gujarat Lionsin season 2016
# Mumbai Indians won with highest margin of 146.0 against Delhi Daredevilsin season 2017
# Mumbai Indians won with highest margin of 102.0 against Kolkata Knight Ridersin season 2018
# Sunrisers Hyderabad won with highest margin of 118.0 against Royal Challengers Bangalorein season 2019
# Kings XI Punjab won with highest margin of 97.0 against Royal Challengers Bangalorein season 2020/21
# Kolkata Knight Riders won with highest margin of 86.0 against Rajasthan Royalsin season 2021
# Chennai Super Kings won with highest margin of 91.0 against Delhi Capitalsin season 2022

# %% [markdown]
# **Head on head encounters : Team vs Team (win count on each other)**

# %% [markdown]
# <a id="4.8"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🏆Head on head encounters : Team vs Team (win count on each other)</div>

# %%
print(Back.GREEN+ Style.BRIGHT+'Head on head encounters : Team vs Team (win count on each other)'+ Style.RESET_ALL)
df1=match_data[['winningteam','win_against']].groupby(['winningteam','win_against']).agg(win_count=('win_against','count'))
df2=df1.pivot_table('win_count', ['winningteam'], 'win_against')
df2.style.background_gradient("plasma")
# Out:
# Head on head encounters : Team vs Team (win count on each other)
# <style type="text/css">
# #T_20db1_row0_col0, #T_20db1_row0_col4, #T_20db1_row0_col14, #T_20db1_row0_col15, #T_20db1_row1_col1, #T_20db1_row1_col2, #T_20db1_row1_col4, #T_20db1_row1_col12, #T_20db1_row1_col14, #T_20db1_row1_col15, #T_20db1_row1_col17, #T_20db1_row2_col1, #T_20db1_row2_col2, #T_20db1_row2_col3, #T_20db1_row2_col4, #T_20db1_row2_col7, #T_20db1_row2_col11, #T_20db1_row2_col14, #T_20db1_row2_col15, #T_20db1_row3_col2, #T_20db1_row3_col3, #T_20db1_row3_col12, #T_20db1_row3_col15, #T_20db1_row4_col0, #T_20db1_row4_col1, #T_20db1_row4_col2, #T_20db1_row4_col4, #T_20db1_row4_col7, #T_20db1_row4_col11, #T_20db1_row4_col12, #T_20db1_row4_col13, #T_20db1_row4_col17, #T_20db1_row5_col1, #T_20db1_row5_col3, #T_20db1_row5_col4, #T_20db1_row5_col6, #T_20db1_row5_col7, #T_20db1_row5_col10, #T_20db1_row5_col11, #T_20db1_row5_col14, #T_20db1_row5_col15, #T_20db1_row6_col6, #T_20db1_row6_col12, #T_20db1_row7_col1, #T_20db1_row7_col2, #T_20db1_row7_col4, #T_20db1_row7_col6, #T_20db1_row7_col7, #T_20db1_row7_col11, #T_20db1_row7_col12, #T_20db1_row7_col14, #T_20db1_row7_col15, #T_20db1_row7_col16, #T_20db1_row7_col17, #T_20db1_row8_col7, #T_20db1_row8_col8, #T_20db1_row9_col1, #T_20db1_row9_col3, #T_20db1_row9_col4, #T_20db1_row9_col6, #T_20db1_row9_col7, #T_20db1_row9_col11, #T_20db1_row9_col13, #T_20db1_row9_col14, #T_20db1_row9_col15, #T_20db1_row9_col16, #T_20db1_row10_col7, #T_20db1_row10_col10, #T_20db1_row11_col2, #T_20db1_row11_col4, #T_20db1_row11_col11, #T_20db1_row11_col12, #T_20db1_row11_col14, #T_20db1_row11_col15, #T_20db1_row11_col16, #T_20db1_row11_col17, #T_20db1_row12_col1, #T_20db1_row12_col2, #T_20db1_row12_col3, #T_20db1_row12_col4, #T_20db1_row12_col6, #T_20db1_row12_col7, #T_20db1_row12_col11, #T_20db1_row12_col12, #T_20db1_row12_col14, #T_20db1_row12_col15, #T_20db1_row13_col4, #T_20db1_row13_col13, #T_20db1_row13_col14, #T_20db1_row13_col15, #T_20db1_row14_col0, #T_20db1_row14_col1, #T_20db1_row14_col2, #T_20db1_row14_col3, #T_20db1_row14_col7, #T_20db1_row14_col11, #T_20db1_row14_col12, #T_20db1_row14_col13, #T_20db1_row14_col14, #T_20db1_row14_col15, #T_20db1_row15_col0, #T_20db1_row15_col1, #T_20db1_row15_col2, #T_20db1_row15_col4, #T_20db1_row15_col7, #T_20db1_row15_col8, #T_20db1_row15_col11, #T_20db1_row15_col12, #T_20db1_row15_col13, #T_20db1_row15_col14, #T_20db1_row15_col15, #T_20db1_row15_col16, #T_20db1_row16_col14, #T_20db1_row16_col16, #T_20db1_row17_col1, #T_20db1_row17_col7, #T_20db1_row17_col14, #T_20db1_row17_col17 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_20db1_row0_col1, #T_20db1_row8_col16, #T_20db1_row10_col1 {
#   background-color: #fdb42f;
#   color: #000000;
# }
# #T_20db1_row0_col2 {
#   background-color: #fca636;
#   color: #000000;
# }
# #T_20db1_row0_col3, #T_20db1_row6_col10, #T_20db1_row13_col10 {
#   background-color: #feb82c;
#   color: #000000;
# }
# #T_20db1_row0_col5, #T_20db1_row0_col7, #T_20db1_row0_col9, #T_20db1_row0_col12, #T_20db1_row1_col5, #T_20db1_row1_col7, #T_20db1_row1_col9, #T_20db1_row2_col5, #T_20db1_row2_col9, #T_20db1_row3_col5, #T_20db1_row3_col7, #T_20db1_row3_col9, #T_20db1_row4_col3, #T_20db1_row4_col5, #T_20db1_row4_col9, #T_20db1_row4_col14, #T_20db1_row5_col2, #T_20db1_row5_col5, #T_20db1_row5_col8, #T_20db1_row5_col9, #T_20db1_row5_col12, #T_20db1_row5_col16, #T_20db1_row5_col17, #T_20db1_row6_col5, #T_20db1_row6_col7, #T_20db1_row6_col9, #T_20db1_row6_col14, #T_20db1_row6_col15, #T_20db1_row7_col0, #T_20db1_row7_col3, #T_20db1_row7_col5, #T_20db1_row7_col9, #T_20db1_row7_col10, #T_20db1_row7_col13, #T_20db1_row8_col4, #T_20db1_row8_col5, #T_20db1_row8_col9, #T_20db1_row8_col14, #T_20db1_row9_col0, #T_20db1_row9_col5, #T_20db1_row9_col9, #T_20db1_row9_col12, #T_20db1_row9_col17, #T_20db1_row10_col5, #T_20db1_row10_col9, #T_20db1_row10_col12, #T_20db1_row10_col14, #T_20db1_row10_col15, #T_20db1_row11_col1, #T_20db1_row11_col5, #T_20db1_row11_col7, #T_20db1_row11_col8, #T_20db1_row11_col9, #T_20db1_row11_col10, #T_20db1_row11_col13, #T_20db1_row12_col5, #T_20db1_row12_col8, #T_20db1_row12_col9, #T_20db1_row12_col13, #T_20db1_row13_col5, #T_20db1_row13_col7, #T_20db1_row13_col9, #T_20db1_row14_col4, #T_20db1_row14_col5, #T_20db1_row14_col6, #T_20db1_row14_col8, #T_20db1_row14_col9, #T_20db1_row15_col5, #T_20db1_row15_col6, #T_20db1_row15_col9, #T_20db1_row15_col10, #T_20db1_row15_col17, #T_20db1_row16_col5, #T_20db1_row16_col9, #T_20db1_row16_col12, #T_20db1_row17_col5, #T_20db1_row17_col9, #T_20db1_row17_col11, #T_20db1_row17_col15 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_20db1_row0_col6, #T_20db1_row0_col8, #T_20db1_row10_col6 {
#   background-color: #f99a3e;
#   color: #000000;
# }
# #T_20db1_row0_col10, #T_20db1_row0_col13, #T_20db1_row0_col16, #T_20db1_row2_col12, #T_20db1_row3_col1, #T_20db1_row3_col14, #T_20db1_row4_col15, #T_20db1_row6_col1, #T_20db1_row8_col1, #T_20db1_row8_col6, #T_20db1_row8_col15, #T_20db1_row8_col17, #T_20db1_row10_col0, #T_20db1_row10_col2, #T_20db1_row10_col8, #T_20db1_row10_col11, #T_20db1_row13_col1, #T_20db1_row16_col3, #T_20db1_row16_col7, #T_20db1_row16_col11, #T_20db1_row16_col15, #T_20db1_row17_col4 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_20db1_row0_col11, #T_20db1_row8_col11, #T_20db1_row13_col11, #T_20db1_row16_col1 {
#   background-color: #ed7953;
#   color: #f1f1f1;
# }
# #T_20db1_row0_col17, #T_20db1_row16_col13 {
#   background-color: #febd2a;
#   color: #000000;
# }
# #T_20db1_row1_col0, #T_20db1_row2_col0 {
#   background-color: #5901a5;
#   color: #f1f1f1;
# }
# #T_20db1_row1_col3, #T_20db1_row1_col10, #T_20db1_row2_col10 {
#   background-color: #7701a8;
#   color: #f1f1f1;
# }
# #T_20db1_row1_col6, #T_20db1_row11_col6 {
#   background-color: #4903a0;
#   color: #f1f1f1;
# }
# #T_20db1_row1_col8, #T_20db1_row7_col8, #T_20db1_row9_col8 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_20db1_row1_col11, #T_20db1_row3_col8, #T_20db1_row3_col11, #T_20db1_row6_col11, #T_20db1_row8_col12, #T_20db1_row13_col12, #T_20db1_row17_col8, #T_20db1_row17_col12 {
#   background-color: #9c179e;
#   color: #f1f1f1;
# }
# #T_20db1_row1_col13, #T_20db1_row12_col17, #T_20db1_row14_col17 {
#   background-color: #350498;
#   color: #f1f1f1;
# }
# #T_20db1_row1_col16, #T_20db1_row3_col16 {
#   background-color: #8808a6;
#   color: #f1f1f1;
# }
# #T_20db1_row2_col6, #T_20db1_row4_col6 {
#   background-color: #2f0596;
#   color: #f1f1f1;
# }
# #T_20db1_row2_col8 {
#   background-color: #7801a8;
#   color: #f1f1f1;
# }
# #T_20db1_row2_col13, #T_20db1_row2_col17 {
#   background-color: #a31e9a;
#   color: #f1f1f1;
# }
# #T_20db1_row2_col16 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_20db1_row3_col0 {
#   background-color: #8305a7;
#   color: #f1f1f1;
# }
# #T_20db1_row3_col4, #T_20db1_row13_col17, #T_20db1_row16_col4, #T_20db1_row17_col13 {
#   background-color: #cc4778;
#   color: #f1f1f1;
# }
# #T_20db1_row3_col6 {
#   background-color: #c43e7f;
#   color: #f1f1f1;
# }
# #T_20db1_row3_col10, #T_20db1_row10_col3, #T_20db1_row13_col3 {
#   background-color: #fa9b3d;
#   color: #000000;
# }
# #T_20db1_row3_col13 {
#   background-color: #b83289;
#   color: #f1f1f1;
# }
# #T_20db1_row3_col17 {
#   background-color: #6f00a8;
#   color: #f1f1f1;
# }
# #T_20db1_row4_col8 {
#   background-color: #3f049c;
#   color: #f1f1f1;
# }
# #T_20db1_row4_col10, #T_20db1_row9_col10, #T_20db1_row11_col3, #T_20db1_row12_col10, #T_20db1_row15_col3 {
#   background-color: #370499;
#   color: #f1f1f1;
# }
# #T_20db1_row4_col16, #T_20db1_row14_col16 {
#   background-color: #2e0595;
#   color: #f1f1f1;
# }
# #T_20db1_row5_col0, #T_20db1_row11_col0 {
#   background-color: #2c0594;
#   color: #f1f1f1;
# }
# #T_20db1_row5_col13 {
#   background-color: #5302a3;
#   color: #f1f1f1;
# }
# #T_20db1_row6_col0, #T_20db1_row8_col0 {
#   background-color: #b6308b;
#   color: #f1f1f1;
# }
# #T_20db1_row6_col2, #T_20db1_row9_col2, #T_20db1_row13_col2 {
#   background-color: #6a00a8;
#   color: #f1f1f1;
# }
# #T_20db1_row6_col3, #T_20db1_row8_col3, #T_20db1_row16_col10 {
#   background-color: #fad824;
#   color: #000000;
# }
# #T_20db1_row6_col4, #T_20db1_row10_col4 {
#   background-color: #7e03a8;
#   color: #f1f1f1;
# }
# #T_20db1_row6_col8 {
#   background-color: #ab2494;
#   c

# %% [markdown]
# <a id="4.9"></a>
# ### <div style="text-align: left; background-color: #58a9db;  color: black; padding: 14px; line-height: 0.5;"> 🏟️Count of matches conducted at each venue</div>

# %%
venue_df=match_data.groupby('venue').agg(match_count=('venue', 'count')).reset_index().sort_values('match_count', ascending=False)

f = plt.figure()
f.set_figwidth(15)
f.set_figheight(4)
plt.bar(venue_df['venue'], venue_df['match_count'], color ='blue',width = 0.4)
plt.xlabel("Venue", fontsize=12, fontweight='bold') 
plt.ylabel("No. of Matches", fontsize=12, fontweight='bold')
plt.xticks(rotation=90)
plt.title("Count of matches at leading venues", fontsize=15, color='red', fontweight='bold') 
plt.show()

# %% [markdown]
# <div style="text-align: left; background-color: #e1f0fa;  color: black; padding: 14px; line-height: 1.0;"> <b>🕵️‍♂️Observation:</b>
#     Eden Gardens has hosted highest number of IPL Matches</div>

# %% [markdown]
# <a id="5"></a>
# # <p style="text-align: Center; background-color: #147eb0;  color: black; padding: 14px; line-height: 0.5;"> 🏆Thank You🏆</p>
# <p style="text-align: left; background-color: #147eb0;  color: black; padding: 14px; line-height: 1.5;"> <b>Thank You</b> for taking time to go through the above analysis. Do comment and Upvote if you like my work.</p>
